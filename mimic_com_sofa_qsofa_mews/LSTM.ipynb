# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.metrics import accuracy_score, roc_auc_score, precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay, roc_curve, auc, precision_recall_curve, average_precision_score
import matplotlib.pyplot as plt

# %% [markdown]
# ## Carregar e tratar a base

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler  # <-- Troca aqui
import joblib
import numpy as np


# Carregar os dados
data = np.load("mimic_X_y_mask_10j.npz")
X = data['X']
y = data['y']
mask = data['mask']

# Balanceamento
idx_sepse = np.where(y == 1)[0]
idx_nsepse = np.where(y == 0)[0]
n = min(len(idx_sepse), len(idx_nsepse))
idx_balanced = np.concatenate([idx_sepse[:n], idx_nsepse[:n]])
np.random.shuffle(idx_balanced)

X_bal = X[idx_balanced]
y_bal = y[idx_balanced]
mask_bal = mask[idx_balanced]

# Divisão treino/val/teste
from sklearn.model_selection import train_test_split

X_train, X_temp, y_train, y_temp, mask_train, mask_temp = train_test_split(
    X_bal, y_bal, mask_bal, test_size=0.30, random_state=42, stratify=y_bal)

X_val, X_test, y_val, y_test, mask_val, mask_test = train_test_split(
    X_temp, y_temp, mask_temp, test_size=0.50, random_state=42, stratify=y_temp)

# Normalização segura por feature
def normalize_split_data(X_train, X_val, X_test):
    n_samples, n_janelas, n_features = X_train.shape
    X_train_norm = np.zeros_like(X_train)
    X_val_norm = np.zeros_like(X_val)
    X_test_norm = np.zeros_like(X_test)
    scalers = []

    for i in range(n_features):
        scaler = StandardScaler()  # <-- Troca aqui
        # scaler = MinMaxScaler()
        feat_train = X_train[:, :, i].reshape(-1, 1)
        scaler.fit(feat_train)  # Ajusta SOMENTE no treino

        # Aplica a mesma escala
        X_train_norm[:, :, i] = scaler.transform(feat_train).reshape(n_samples, n_janelas)
        X_val_norm[:, :, i] = scaler.transform(X_val[:, :, i].reshape(-1, 1)).reshape(X_val.shape[0], n_janelas)
        X_test_norm[:, :, i] = scaler.transform(X_test[:, :, i].reshape(-1, 1)).reshape(X_test.shape[0], n_janelas)

        scalers.append(scaler)

    return X_train_norm, X_val_norm, X_test_norm, scalers

# Executar normalização
X_train_norm, X_val_norm, X_test_norm, scalers = normalize_split_data(X_train, X_val, X_test)

# Salvar scalers
joblib.dump(scalers, "scalers_standard_lstm.pkl")  # <-- Nome atualizado

# Atualizar variáveis do pipeline
X_train, X_val, X_test = X_train_norm, X_val_norm, X_test_norm

print("✅ Normalização segura concluída com StandardScaler e scalers salvos!")
# Out:
# ✅ Normalização segura concluída com StandardScaler e scalers salvos!

# %% [markdown]
# ## Carregar sem tratar a base (V.1)

# %% [markdown]
# ### Divisão dos dados em treino, validação e teste
#
# - **Objetivo:** Separar o conjunto balanceado em três partes: treino (70%), validação (15%) e teste (15%).
# - **Como:**
#   - Primeiro, separa 70% para treino e 30% para validação+teste.
#   - Depois, divide os 30% restantes igualmente entre validação e teste.
# - **Estratificação:** A divisão mantém a proporção das classes (sepse/não sepse) em todos os conjuntos.
# - **Importância:** Garante avaliação justa do modelo e evita vazamento de dados entre treino e teste.

# %% [markdown]
# ### Construção do modelo LSTM
#
# - **Definição da entrada:** O modelo recebe sequências no formato `(janelas, variáveis)` para cada paciente.
# - **Máscara:** A camada `Masking` faz o modelo ignorar posições preenchidas com zero (usadas para padding).
# - **LSTM:** Camada principal que processa as sequências temporais, capturando padrões ao longo do tempo.
# - **Dropout:** Ajuda a evitar overfitting, desligando aleatoriamente parte dos neurônios durante o treino.
# - **Dense:** Camada totalmente conectada para refinar a representação.
# - **Saída:** Camada final com ativação sigmoide para prever a probabilidade de sepse (0 ou 1).

# %% [markdown]
# ## LSTM

# %%
# Definir a forma da entrada (janelas, variáveis)
input_shape = X_train.shape[1:]  # (10, 8)

# Construir o modelo
inputs = tf.keras.Input(shape=input_shape)
x = layers.Masking(mask_value=0.0)(inputs)
x = layers.LSTM(64, return_sequences=False)(x)
x = layers.Dropout(0.3)(x)
x = layers.Dense(32, activation='relu')(x)
outputs = layers.Dense(1, activation='sigmoid')(x)

model_lstm = models.Model(inputs, outputs)

# %% [markdown]
# ### Compilação do modelo LSTM
#
# - **O que é feito:**
#   Esta célula configura como o modelo LSTM será treinado, definindo o otimizador, a função de perda e as métricas de avaliação.
#
# - **Parâmetros definidos:**
#   - **optimizer='adam':**
#     Utiliza o otimizador Adam, que é eficiente e amplamente usado em deep learning por ajustar automaticamente a taxa de aprendizado durante o treinamento.
#   - **loss='binary_crossentropy':**
#     Define a função de perda como entropia cruzada binária, adequada para problemas de classificação binária (sepse ou não).
#   - **metrics:**
#     Lista de métricas que serão monitoradas durante o treinamento e validação:
#     - **BinaryAccuracy (accuracy):** Mede a proporção de previsões corretas (acertos) entre as amostras.
#     - **AUC (Área sob a curva ROC):** Avalia a capacidade do modelo em distinguir entre as classes, considerando diferentes limiares de decisão.
#     - **Recall (Sensibilidade):** Mede a proporção de casos positivos corretamente identificados (importante para não perder casos de sepse).
#     - **Precision (Precisão):** Mede a proporção de previsões positivas que realmente são positivas (importante para evitar alarmes falsos).
#
# - **Resumo:**
#   Com essa configuração, o modelo será treinado de forma eficiente e avaliado por métricas que ajudam a entender não só o acerto geral, mas também a capacidade de identificar corretamente casos de sepse e evitar falsos positivos.

# %%
model_lstm.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=[
        tf.keras.metrics.BinaryAccuracy(name='accuracy'),
        tf.keras.metrics.AUC(name='auc'),
        tf.keras.metrics.Recall(name='recall'),
        tf.keras.metrics.Precision(name='precision')
    ]
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %% [markdown]
# ### Treinamento do modelo LSTM
#
# - **O que está sendo feito:**
#   Esta célula inicia o treinamento do modelo LSTM usando os dados de treino e validação.
#
# - **Parâmetros principais:**
#   - `X_train, y_train`: Dados de entrada e rótulos para o treinamento do modelo.
#   - `validation_data=(X_val, y_val)`: Dados separados para validação, permitindo monitorar o desempenho do modelo em dados não vistos durante o treino.
#   - `epochs=50`: O modelo será treinado por até 50 ciclos completos sobre o conjunto de treino. Um número maior de épocas pode ajudar o modelo a aprender melhor, mas também pode causar overfitting se exagerado.
#   - `batch_size=64`: O modelo atualiza os pesos a cada 64 amostras. Batches maiores podem acelerar o treinamento, mas exigem mais memória.
#   - `verbose=2`: Controla o nível de detalhamento dos logs durante o treinamento (2 mostra uma linha por época).
#
# - **Por que usar validação?**
#   O conjunto de validação serve para acompanhar se o modelo está realmente aprendendo padrões úteis ou apenas decorando os dados de treino (overfitting). Assim, é possível ajustar hiperparâmetros e escolher o melhor modelo.
#
# - **Resumo:**
#   Ao final desse processo, o histórico de treinamento (`history`) terá informações sobre a evolução das métricas de desempenho em treino e validação, permitindo avaliar e comparar os resultados.

# %%
# Treinamento do modelo
history = model_lstm.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=50,
    batch_size=64,
    verbose=2
)
# Out:
# Epoch 1/50
# 3701/3701 - 18s - 5ms/step - accuracy: 0.6979 - auc: 0.7672 - loss: 0.5756 - precision: 0.6911 - recall: 0.7157 - val_accuracy: 0.7128 - val_auc: 0.7865 - val_loss: 0.5562 - val_precision: 0.7133 - val_recall: 0.7118
# Epoch 2/50
# 3701/3701 - 20s - 5ms/step - accuracy: 0.7165 - auc: 0.7914 - loss: 0.5512 - precision: 0.7153 - recall: 0.7192 - val_accuracy: 0.7280 - val_auc: 0.8045 - val_loss: 0.5379 - val_precision: 0.7406 - val_recall: 0.7018
# Epoch 3/50
# 3701/3701 - 25s - 7ms/step - accuracy: 0.7294 - auc: 0.8072 - loss: 0.5335 - precision: 0.7318 - recall: 0.7243 - val_accuracy: 0.7336 - val_auc: 0.8149 - val_loss: 0.5256 - val_precision: 0.7554 - val_recall: 0.6910
# Epoch 4/50
# 3701/3701 - 33s - 9ms/step - accuracy: 0.7424 - auc: 0.8214 - loss: 0.5168 - precision: 0.7487 - recall: 0.7298 - val_accuracy: 0.7465 - val_auc: 0.8281 - val_loss: 0.5107 - val_precision: 0.7713 - val_recall: 0.7009
# Epoch 5/50
# 3701/3701 - 16s - 4ms/step - accuracy: 0.7528 - auc: 0.8334 - loss: 0.5016 - precision: 0.7609 - recall: 0.7374 - val_accuracy: 0.7542 - val_auc: 0.8362 - val_loss: 0.4994 - val_precision: 0.7515 - val_recall: 0.7597
# Epoch 6/50
# 3701/3701 - 23s - 6ms/step - accuracy: 0.7636 - auc: 0.8443 - loss: 0.4870 - precision: 0.7728 - recall: 0.7466 - val_accuracy: 0.7653 - val_auc: 0.8469 - val_loss: 0.4830 - val_precision: 0.7763 - val_recall: 0.7455
# Epoch 7/50
# 3701/3701 - 35s - 10ms/step - accuracy: 0.7731 - auc: 0.8542 - loss: 0.4733 - precision: 0.7830 - recall: 0.7554 - val_accuracy: 0.7716 - val_auc: 0.8527 - val_loss: 0.4753 - val_precision: 0.7860 - val_recall: 0.7466
# Epoch 8/50
# 3701/3701 - 17s - 4ms/step - accuracy: 0.7801 - auc: 0.8620 - loss: 0.4613 - precision: 0.7916 - recall: 0.7605 - val_accuracy: 0.7776 - val_auc: 0.8606 - val_loss: 0.4638 - val_precision: 0.7824 - val_recall: 0.7690
# Epoch 9/50
# 3701/3701 - 16s - 4ms/step - accuracy: 0.7860 - auc: 0.8685 - loss: 0.4512 - precision: 0.7984 - recall: 0.7652 - val_accuracy: 0.7828 - val_auc: 0.8655 - val_loss: 0.4566 - val_precision: 0.7854 - val_recall: 0.7783
# Epoch 10/50
# 3701/3701 - 20s - 5ms/step - accuracy: 0.7928 - auc: 0.8757 - loss: 0.4396 - precision: 0.8062 - recall: 0.7709 - val_accuracy: 0.7884 - val_auc: 0.8709 - val_loss: 0.4485 - val_precision: 0.8053 - val_recall: 0.7606
# Epoch 11/50
# 3701/3701 - 18s - 5ms/step - accuracy: 0.7990 - auc: 0.8810 - loss: 0.4309 - precision: 0.8130 - recall: 0.7767 - val_accuracy: 0.7937 - val_auc: 0.8757 - val_loss: 0.4403 - val_precision: 0.8075 - val_recall: 0.7712
# Epoch 12/50
# 3701/3701 - 18s - 5ms/step - accuracy: 0.8032 - auc: 0.8861 - loss: 0.4224 - precision: 0.8172 - recall: 0.7811 - val_accuracy: 0.7946 - val_auc: 0.8772 - val_loss: 0.4378 - val_precision: 0.8023 - val_recall: 0.7820
# Epoch 13/50
# 3701/3701 - 23s - 6ms/step - accuracy: 0.8079 - auc: 0.8904 - loss: 0.4148 - precision: 0.8229 - recall: 0.7845 - val_accuracy: 0.7994 - val_auc: 0.8813 - val_loss: 0.4310 - val_precision: 0.8131 - val_recall: 0.7775
# Epoch 14/50
# 3701/3701 - 37s - 10ms/step - accuracy: 0.8123 - auc: 0.8947 - loss: 0.4073 - precision: 0.8272 - recall: 0.7895 - val_accuracy: 0.8043 - val_auc: 0.8854 - val_loss: 0.4240 - val_precision: 0.8153 - val_recall: 0.7868
# Epoch 15/50
# 3701/3701 - 18s - 5ms/step - accuracy: 0.8157 - auc: 0.8981 - loss: 0.4011 - precision: 0.8305 - recall: 0.7933 - val_accuracy: 0.8040 - val_auc: 0.8864 - val_loss: 0.4241 - val_precision: 0.8305 - val_recall: 0.7640
# Epoch 16/50
# 3701/3701 - 18s - 5ms/step - accuracy: 0.8194 - auc: 0.9011 - loss: 0.3955 - precision: 0.8357 - recall: 0.7952 - val_accuracy: 0.8074 - val_auc: 0.8887 - val_loss: 0.4196 - val_precision: 0.8327 - val_recall: 0.7693
# Epoch 17/50
# 3701/3701 - 18s - 5ms/step - accuracy: 0.8232 - auc: 0.9045 - loss: 0.3890 - precision: 0.8388 - recall: 0.8002 - val_accuracy: 0.8080 - val_auc: 0.8903 - val_loss: 0.4164 - val_precision: 0.8127 - val_recall: 0.8004
# Epoch 18/50
# 3701/3701 - 18s - 5ms/step - accuracy: 0.8254 - auc: 0.9071 - loss: 0.3840 - precision: 0.8407 - recall: 0.8030 - val_accuracy: 0.8130 - val_auc: 0.8925 - val_loss: 0.4137 - val_precision: 0.8378 - val_recall: 0.7764
# Epoch 19/50
# 3701/3701 - 18s - 5ms/step - accuracy: 0.8284 - auc: 0.9096 - loss: 0.3788 - precision: 0.8448 - recall: 0.8045 - val_accuracy: 0.8131 - val_auc: 0.8940 - val_loss: 0.4089 - val_precision: 0.8216 - val_recall: 0.7998
# Epoch 20/50
# 3701/3701 - 19s - 5ms/step - accuracy: 0.8312 - auc: 0.9122 - loss: 0.3739 - precision: 0.8474 - recall: 0.8079 - val_accuracy: 0.8135 - val_auc: 0.8943 - val_loss: 0.4087 - val_precision: 0.8296 - val_recall: 0.7891
# Epoch 21/50
# 3701/3701 - 19s - 5ms/step - accuracy: 0.8338 - auc: 0.9142 - loss: 0.3696 - precision: 0.8491 - recall: 0.8118 - val_accuracy: 0.8172 - val_auc: 0.8972 - val_loss: 0.4039 - val_precision: 0.8394 - val_recall: 0.7845
# Epoch 22/50
# 3701/3701 - 20s - 5ms/step - accuracy: 0.8364 - auc: 0.9163 - loss: 0.3653 - precision: 0.8532 - recall: 0.8128 - val_accuracy: 0.8180 - val_auc: 0.8979 - val_loss: 0.4044 - val_precision: 0.8259 - val_recall: 0.8059
# Epoch 23/50
# 3701/3701 - 20s - 5ms/step - accuracy: 0.8373 - auc: 0.9178 - loss: 0.3619 - precision: 0.8535 - recall: 0.8144 - val_accuracy: 0.8193 - val_auc: 0.8989 - val_loss: 0.4011 - val_precision: 0.8539 - val_recall: 0.7705
# Epoch 24/50
# 3701/3701 - 19s - 5ms/step - accuracy: 0.8402 - auc: 0.9201 - loss: 0.3570 - precision: 0.8569 - recall: 0.8168 - val_accuracy: 0.8227 - val_auc: 0.9013 - val_loss: 0.3970 - val_precision: 0.8450 - val_recall: 0.7903
# Epoch 25/50
# 3701/3701 - 21s - 6ms/step - accuracy: 0.8422 - auc: 0.9214 - loss: 0.3544 - precision: 0.8581 - recall: 0.8201 - val_accuracy: 0.8202 - val_auc: 0.9000 - val_loss: 0.3988 - val_precision: 0.8436 - val_recall: 0.7861
# Epoch 26/50
# 3701/3701 - 25s - 7ms/step - accuracy: 0.8436 - auc: 0.9231 - loss: 0.3505 - precision: 0.8599 - recall: 0.8210 - val_accuracy: 0.8234 - val_auc: 0.9022 - val_loss: 0.3951 - val_precision: 0.8363 - val_recall: 0.8043
# Epoch 27/50
# 3701/3701 - 42s - 11ms/step - accuracy: 0.8453 - auc: 0.9242 - loss: 0.3481 - precision: 0.8617 - recall: 0.8226 - val_accuracy: 0.8220 - val_auc: 0.9026 - val_loss: 0.3935 - val_precision: 0.8403 - val_recall: 0.7952
# Epoch 28/50
# 3701/3701 - 23s - 6ms/step - accuracy: 0.8476 - auc: 0.9260 - loss: 0.3442 - precision: 0.8640 - recall: 0.8252 - val_accuracy: 0.8246 - val_auc: 0.9042 - val_loss: 0.3912 - val_precision: 0.8319 - val_recall: 0.8136
# Epoch 29/50
# 3701/3701 - 32s - 9ms/step - accuracy: 0.8486 - auc: 0.9270 - loss: 0.3419 - precision: 0.8650 - recall: 0.8261 - val_accuracy: 0.8256 - val_auc: 0.9049 - val_loss: 0.3899 - val_precision: 0.8383 - val_recall: 0.8069
# Epoch 30/50
# 3701/3701 - 18s - 5ms/step - accuracy: 0.8502 - auc: 0.9279 - loss: 0.3398 - precision: 0.8667 - recall: 0.8278 - val_accuracy: 0.8244 - val_auc: 0.9043 - val_loss: 0.3914 - val_precision: 0.8306 - val_recall: 0.8151
# Epoch 31/50
# 3701/3701 - 19s - 5ms/step - accuracy: 0.8515 - auc: 0.9299 - loss: 0.3352 - precision: 0.8678 - recall: 0.8294 - val_accuracy: 0.8273 - val_auc: 0.9062 - val_loss: 0.3881 - val_precision: 0.8537 - val_recall: 0.7901
# Epoch 32/50
# 3701/3701 - 21s - 6ms/step - accuracy: 0.8528 - auc: 0.9304 - loss: 0.3341 - precision: 0.8685 - recall: 0.8315 - val_accuracy: 0.8275 - val_auc: 0.9070 - val_loss: 0.3860 - val_precision: 0.8538 - val_recall: 0.7902
# Epoch 33/50
# 3701/3701 - 21s - 6ms/step - accuracy: 0.8542 - auc: 0.9316 - loss: 0.3314 - precision: 0.8704 - recall: 0.8324 - val_accuracy: 0.8309 - val_auc: 0.9094 - val_loss: 0.3820 - val_precision: 0.8407 - val_recall: 0.8164
# Epoch 34/50
# 3701/3701 - 21s - 6ms/step - accuracy: 0.8552 - auc: 0.9327 - loss: 0.3287 - precision: 0.8712 - recall: 0.8336 - val_accuracy: 0.8317 - val_auc: 0.9106 - val_loss: 0.3806 - val_precision: 0.8541 - val_recall: 0.8001
# Epoch 35/50
# 3701/3701 - 21s - 6ms/step - accuracy: 0.8562 - auc: 0.9335 - loss: 0.3267 - precision: 0.8730 - recall: 0.8336 - val_accuracy: 0.8312 - val_auc: 0.9103 - val_loss: 0.3798 - val_precision: 0.8374 - val_recall: 0.8221
# Epoch 36/50
# 3701/3701 - 21s - 6ms/step - accuracy: 0.8586 - auc: 0.9351 - loss: 0.3229 - precision: 0.8751 - recall: 0.8365 - val_accuracy: 0.8298 - val_auc: 0.9092 - val_loss: 0.3831 - val_precision: 0.8460 - val_recall: 0.8064
# Epoch 37/50
# 3701/3701 - 21s - 6ms/step - accuracy: 0.8594 - auc: 0.9357 - loss: 0.3212 - precision: 0.8760 - recall: 0.8374 - val_accuracy: 0.8303 - val_auc: 0.9087 - val_loss: 0.3858 - val_precision: 0.8444 - val_recall: 0.8099
# Epoch 38/50
# 3701/3701 - 21s - 6ms/step - accuracy: 0.8598 - auc: 0.9364 - loss: 0.3197 - precision: 0.8757 - recall: 0.8388 - val_accuracy: 0.8326 - val_auc: 0.9109 - val_loss: 0.3793 - val_precision: 0.8584 - val_recall: 0.7967
# Epoch 39/50
# 3701/3701 - 21s - 6ms/step - accuracy: 0.8610 - auc: 0.9373 - loss: 0.3172 - precision: 0.8768 - recall: 0.8400 - val_accuracy: 0.8315 - val_auc: 0.9102 - val_loss: 0.3826 - val_precision: 0.8449 - val_recall: 0.8121
# Epoch 40/50
# 3701/3701 - 21s - 6ms/step - accuracy: 0.8632 - auc: 0.9386 - loss: 0.3141 - precision: 0.8798 - recall: 0.8415 - val_accuracy: 0.8343 - val_auc: 0.9113 - val_loss: 0.3784 - val_precision: 0.8525 - val_recall: 0.8085
# Epoch 41/50
# 3701/3701 - 21s - 6ms/step - accuracy: 0.8631 - auc: 0.9388 - loss: 0.3137 - precision: 0.8798 - recall: 0.8412 - val_accuracy: 0.8345 - val_auc: 0.9123 - val_loss: 0.3767 - val_precision: 0.8486 - val_recall: 0.8142
# Epoch 42/50
# 3701/3701 - 21s - 6ms/step - accuracy: 0.8640 - auc: 0.9392 - loss: 0.3126 - precision: 0.8798 - recall: 0.8431 - val_accuracy: 0.8332 - val_auc: 0.9101 - val_loss: 0.3829 - val_precision: 0.8549 - val_recall: 0.8026
# Epoch 43/50
# 3701/3701 - 21s - 6ms/step - accuracy: 0.8647 - auc: 0.9403 - loss: 0.3098 - precision: 0.8808 - recall: 0.8437 - val_accuracy: 0.8322 - val_auc: 0.9120 - val_loss: 0.3808 - val_precision: 0.8404 - val_recall: 0.8201
# Epoch 44/50
# 3701/3701 - 22s - 6ms/step - accuracy: 0.8660 - auc: 0.9409 - loss: 0.3083 - precision: 0.8821 - recall: 0.8450 - val_accuracy: 0.8351 - val_auc: 0.9119 - val_loss: 0.3801 - val_precision: 0.8519 - val_recall: 0.8111
# Epoch 45/50
# 3701/3701 - 22s - 6ms/step - accuracy: 0.8667 - auc: 0.9412 - loss: 0.3074 - precision: 0.8830 - recall: 0.8453 - val_accuracy: 0.8357 - val_auc: 0.9139 - val_loss: 0.3730 - val_precision: 0.8473 - val_recall: 0.8190
# Epoch 46/50
# 3701/3701 - 21s - 6ms/step - accuracy: 0.8681 - auc: 0.9422 - loss: 0.3050 - precision: 0.8847 - recall: 0.8466 - val_accuracy: 0.8368 - val_auc: 0.9144 - val_loss: 0.3727 - val_precision: 0.8563 - val_recall: 0.8094
# Epoch 47/50
# 3701/3701 - 23s - 6ms/step - accuracy: 0.8683 - auc: 0.9426 - loss: 0.3038 - precision: 0.8843 - recall: 0.8475 - val_accuracy: 0.8389 - val_auc: 0.9146 - val_loss: 0.3725 - val_precision: 0.8499 - val_recall: 0.8233
# Epoch 48/50
# 3701/3701 - 24s - 6ms/step - accuracy: 0.8690 - auc: 0.9432 - loss: 0.3025 - precision: 0.8853 - recall: 0.8479 - val_accuracy: 0.8384 - val_auc: 0.9148 - val_loss: 0.3730 - val_precision: 0.8599 - val_recall: 0.8086
# Epoch 49/50
# 3701/3701 - 21s - 6ms/step - accuracy: 0.8704 - auc: 0.9439 - loss: 0.3004 - precision: 0.8870 - recall: 0.8490 - val_accuracy: 0.8384 - val_auc: 0.9146 - val_loss: 0.3725 - val_precision: 0.8572 - val_recall: 0.8122
# Epoch 50/50
# 3701/3701 - 22s - 6ms/step - accuracy: 0.8714 - auc: 0.9446 - loss: 0.2987 - precision: 0.8875 - recall: 0.8507 - val_accuracy: 0.8400 - val_auc: 0.9158 - val_loss: 0.3699 - val_precision: 0.8577 - val_recall: 0.8152

# %%
input_shape = X_train.shape[1:]  # alternativo

inputs = tf.keras.Input(shape=input_shape)
x = layers.Masking(mask_value=0.0)(inputs)
x = layers.Bidirectional(layers.LSTM(64, return_sequences=True))(x)
x = layers.GlobalAveragePooling1D()(x)
x = layers.Dropout(0.2)(x)
x = layers.Dense(32, activation='relu')(x)
outputs = layers.Dense(1, activation='sigmoid')(x)

model_lstm = tf.keras.Model(inputs, outputs)
model_lstm.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=[
        tf.keras.metrics.BinaryAccuracy(name='accuracy'),
        tf.keras.metrics.AUC(name='auc'),
        tf.keras.metrics.Recall(name='recall'),
        tf.keras.metrics.Precision(name='precision')
    ]
)

# Opcional: sample_weight por quantidade de janelas válidas
sample_weights = mask_train.sum(axis=1) / mask_train.shape[1]

# Treinamento
model_lstm.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=50,
    batch_size=64,
    sample_weight=sample_weights,
    verbose=2
)
# Out:
# Epoch 1/50
# 3701/3701 - 35s - 9ms/step - accuracy: 0.7028 - auc: 0.7744 - loss: 0.5529 - precision: 0.6977 - recall: 0.7158 - val_accuracy: 0.7196 - val_auc: 0.7963 - val_loss: 0.5463 - val_precision: 0.7099 - val_recall: 0.7427
# Epoch 2/50
# 3701/3701 - 29s - 8ms/step - accuracy: 0.7241 - auc: 0.8001 - loss: 0.5263 - precision: 0.7224 - recall: 0.7277 - val_accuracy: 0.7342 - val_auc: 0.8138 - val_loss: 0.5261 - val_precision: 0.7311 - val_recall: 0.7409
# Epoch 3/50
# 3701/3701 - 29s - 8ms/step - accuracy: 0.7402 - auc: 0.8188 - loss: 0.5050 - precision: 0.7417 - recall: 0.7369 - val_accuracy: 0.7497 - val_auc: 0.8297 - val_loss: 0.5066 - val_precision: 0.7532 - val_recall: 0.7428
# Epoch 4/50
# 3701/3701 - 29s - 8ms/step - accuracy: 0.7547 - auc: 0.8349 - loss: 0.4846 - precision: 0.7583 - recall: 0.7477 - val_accuracy: 0.7590 - val_auc: 0.8433 - val_loss: 0.4888 - val_precision: 0.7514 - val_recall: 0.7739
# Epoch 5/50
# 3701/3701 - 29s - 8ms/step - accuracy: 0.7670 - auc: 0.8491 - loss: 0.4654 - precision: 0.7732 - recall: 0.7556 - val_accuracy: 0.7723 - val_auc: 0.8532 - val_loss: 0.4753 - val_precision: 0.7859 - val_recall: 0.7485
# Epoch 6/50
# 3701/3701 - 30s - 8ms/step - accuracy: 0.7783 - auc: 0.8616 - loss: 0.4472 - precision: 0.7862 - recall: 0.7645 - val_accuracy: 0.7806 - val_auc: 0.8643 - val_loss: 0.4582 - val_precision: 0.7897 - val_recall: 0.7649
# Epoch 7/50
# 3701/3701 - 29s - 8ms/step - accuracy: 0.7873 - auc: 0.8720 - loss: 0.4308 - precision: 0.7964 - recall: 0.7718 - val_accuracy: 0.7886 - val_auc: 0.8737 - val_loss: 0.4434 - val_precision: 0.8000 - val_recall: 0.7696
# Epoch 8/50
# 3701/3701 - 29s - 8ms/step - accuracy: 0.7966 - auc: 0.8809 - loss: 0.4168 - precision: 0.8068 - recall: 0.7801 - val_accuracy: 0.7938 - val_auc: 0.8788 - val_loss: 0.4357 - val_precision: 0.8120 - val_recall: 0.7645
# Epoch 9/50
# 3701/3701 - 32s - 9ms/step - accuracy: 0.8047 - auc: 0.8887 - loss: 0.4032 - precision: 0.8153 - recall: 0.7880 - val_accuracy: 0.7994 - val_auc: 0.8838 - val_loss: 0.4271 - val_precision: 0.8186 - val_recall: 0.7691
# Epoch 10/50
# 3701/3701 - 31s - 8ms/step - accuracy: 0.8107 - auc: 0.8953 - loss: 0.3914 - precision: 0.8230 - recall: 0.7917 - val_accuracy: 0.8057 - val_auc: 0.8886 - val_loss: 0.4199 - val_precision: 0.8165 - val_recall: 0.7885
# Epoch 11/50
# 3701/3701 - 30s - 8ms/step - accuracy: 0.8183 - auc: 0.9016 - loss: 0.3803 - precision: 0.8308 - recall: 0.7995 - val_accuracy: 0.8082 - val_auc: 0.8934 - val_loss: 0.4108 - val_precision: 0.8190 - val_recall: 0.7913
# Epoch 12/50
# 3701/3701 - 29s - 8ms/step - accuracy: 0.8230 - auc: 0.9062 - loss: 0.3714 - precision: 0.8350 - recall: 0.8051 - val_accuracy: 0.8146 - val_auc: 0.8978 - val_loss: 0.4032 - val_precision: 0.8404 - val_recall: 0.7766
# Epoch 13/50
# 3701/3701 - 29s - 8ms/step - accuracy: 0.8284 - auc: 0.9113 - loss: 0.3612 - precision: 0.8408 - recall: 0.8103 - val_accuracy: 0.8185 - val_auc: 0.9013 - val_loss: 0.3966 - val_precision: 0.8335 - val_recall: 0.7959
# Epoch 14/50
# 3701/3701 - 29s - 8ms/step - accuracy: 0.8336 - auc: 0.9159 - loss: 0.3518 - precision: 0.8462 - recall: 0.8155 - val_accuracy: 0.8214 - val_auc: 0.9040 - val_loss: 0.3919 - val_precision: 0.8365 - val_recall: 0.7991
# Epoch 15/50
# 3701/3701 - 30s - 8ms/step - accuracy: 0.8383 - auc: 0.9197 - loss: 0.3438 - precision: 0.8515 - recall: 0.8196 - val_accuracy: 0.8225 - val_auc: 0.9056 - val_loss: 0.3908 - val_precision: 0.8477 - val_recall: 0.7861
# Epoch 16/50
# 3701/3701 - 30s - 8ms/step - accuracy: 0.8412 - auc: 0.9229 - loss: 0.3367 - precision: 0.8542 - recall: 0.8229 - val_accuracy: 0.8271 - val_auc: 0.9094 - val_loss: 0.3837 - val_precision: 0.8495 - val_recall: 0.7952
# Epoch 17/50
# 3701/3701 - 29s - 8ms/step - accuracy: 0.8460 - auc: 0.9264 - loss: 0.3291 - precision: 0.8583 - recall: 0.8288 - val_accuracy: 0.8296 - val_auc: 0.9112 - val_loss: 0.3780 - val_precision: 0.8459 - val_recall: 0.8060
# Epoch 18/50
# 3701/3701 - 30s - 8ms/step - accuracy: 0.8492 - auc: 0.9296 - loss: 0.3217 - precision: 0.8619 - recall: 0.8316 - val_accuracy: 0.8314 - val_auc: 0.9127 - val_loss: 0.3761 - val_precision: 0.8522 - val_recall: 0.8019
# Epoch 19/50
# 3701/3701 - 29s - 8ms/step - accuracy: 0.8528 - auc: 0.9322 - loss: 0.3154 - precision: 0.8657 - recall: 0.8351 - val_accuracy: 0.8333 - val_auc: 0.9138 - val_loss: 0.3741 - val_precision: 0.8579 - val_recall: 0.7990
# Epoch 20/50
# 3701/3701 - 29s - 8ms/step - accuracy: 0.8559 - auc: 0.9349 - loss: 0.3089 - precision: 0.8689 - recall: 0.8384 - val_accuracy: 0.8343 - val_auc: 0.9153 - val_loss: 0.3723 - val_precision: 0.8555 - val_recall: 0.8046
# Epoch 21/50
# 3701/3701 - 29s - 8ms/step - accuracy: 0.8587 - auc: 0.9370 - loss: 0.3040 - precision: 0.8713 - recall: 0.8418 - val_accuracy: 0.8366 - val_auc: 0.9164 - val_loss: 0.3699 - val_precision: 0.8557 - val_recall: 0.8097
# Epoch 22/50
# 3701/3701 - 29s - 8ms/step - accuracy: 0.8622 - auc: 0.9396 - loss: 0.2974 - precision: 0.8743 - recall: 0.8460 - val_accuracy: 0.8409 - val_auc: 0.9196 - val_loss: 0.3638 - val_precision: 0.8583 - val_recall: 0.8166
# Epoch 23/50
# 3701/3701 - 31s - 8ms/step - accuracy: 0.8641 - auc: 0.9410 - loss: 0.2937 - precision: 0.8771 - recall: 0.8467 - val_accuracy: 0.8408 - val_auc: 0.9196 - val_loss: 0.3639 - val_precision: 0.8532 - val_recall: 0.8232
# Epoch 24/50
# 3701/3701 - 29s - 8ms/step - accuracy: 0.8662 - auc: 0.9430 - loss: 0.2884 - precision: 0.8788 - recall: 0.8495 - val_accuracy: 0.8430 - val_auc: 0.9223 - val_loss: 0.3606 - val_precision: 0.8710 - val_recall: 0.8051
# Epoch 25/50
# 3701/3701 - 30s - 8ms/step - accuracy: 0.8688 - auc: 0.9449 - loss: 0.2837 - precision: 0.8813 - recall: 0.8525 - val_accuracy: 0.8415 - val_auc: 0.9214 - val_loss: 0.3599 - val_precision: 0.8632 - val_recall: 0.8117
# Epoch 26/50
# 3701/3701 - 31s - 8ms/step - accuracy: 0.8709 - auc: 0.9463 - loss: 0.2801 - precision: 0.8834 - recall: 0.8545 - val_accuracy: 0.8450 - val_auc: 0.9230 - val_loss: 0.3589 - val_precision: 0.8616 - val_recall: 0.8220
# Epoch 27/50
# 3701/3701 - 33s - 9ms/step - accuracy: 0.8733 - auc: 0.9479 - loss: 0.2754 - precision: 0.8854 - recall: 0.8575 - val_accuracy: 0.8451 - val_auc: 0.9231 - val_loss: 0.3596 - val_precision: 0.8627 - val_recall: 0.8209
# Epoch 28/50
# 3701/3701 - 33s - 9ms/step - accuracy: 0.8748 - auc: 0.9495 - loss: 0.2712 - precision: 0.8874 - recall: 0.8587 - val_accuracy: 0.8471 - val_auc: 0.9257 - val_loss: 0.3533 - val_precision: 0.8660 - val_recall: 0.8212
# Epoch 29/50
# 3701/3701 - 33s - 9ms/step - accuracy: 0.8759 - auc: 0.9507 - loss: 0.2676 - precision: 0.8884 - recall: 0.8598 - val_accuracy: 0.8475 - val_auc: 0.9260 - val_loss: 0.3522 - val_precision: 0.8664 - val_recall: 0.8218
# Epoch 30/50
# 3701/3701 - 33s - 9ms/step - accuracy: 0.8782 - auc: 0.9520 - loss: 0.2641 - precision: 0.8906 - recall: 0.8623 - val_accuracy: 0.8489 - val_auc: 0.9266 - val_loss: 0.3512 - val_precision: 0.8561 - val_recall: 0.8388
# Epoch 31/50
# 3701/3701 - 33s - 9ms/step - accuracy: 0.8799 - auc: 0.9534 - loss: 0.2600 - precision: 0.8921 - recall: 0.8645 - val_accuracy: 0.8482 - val_auc: 0.9271 - val_loss: 0.3510 - val_precision: 0.8641 - val_recall: 0.8264
# Epoch 32/50
# 3701/3701 - 37s - 10ms/step - accuracy: 0.8822 - auc: 0.9545 - loss: 0.2566 - precision: 0.8943 - recall: 0.8667 - val_accuracy: 0.8503 - val_auc: 0.9280 - val_loss: 0.3516 - val_precision: 0.8521 - val_recall: 0.8477
# Epoch 33/50
# 3701/3701 - 40s - 11ms/step - accuracy: 0.8830 - auc: 0.9555 - loss: 0.2537 - precision: 0.8948 - recall: 0.8680 - val_accuracy: 0.8539 - val_auc: 0.9303 - val_loss: 0.3440 - val_precision: 0.8684 - val_recall: 0.8341
# Epoch 34/50
# 3701/3701 - 39s - 10ms/step - accuracy: 0.8848 - auc: 0.9565 - loss: 0.2511 - precision: 0.8972 - recall: 0.8691 - val_accuracy: 0.8507 - val_auc: 0.9280 - val_loss: 0.3503 - val_precision: 0.8635 - val_recall: 0.8330
# Epoch 35/50
# 3701/3701 - 32s - 9ms/step - accuracy: 0.8851 - auc: 0.9571 - loss: 0.2486 - precision: 0.8973 - recall: 0.8697 - val_accuracy: 0.8516 - val_auc: 0.9292 - val_loss: 0.3504 - val_precision: 0.8561 - val_recall: 0.8453
# Epoch 36/50
# 3701/3701 - 33s - 9ms/step - accuracy: 0.8872 - auc: 0.9581 - loss: 0.2459 - precision: 0.8997 - recall: 0.8717 - val_accuracy: 0.8515 - val_auc: 0.9283 - val_loss: 0.3482 - val_precision: 0.8671 - val_recall: 0.8303
# Epoch 37/50
# 3701/3701 - 32s - 9ms/step - accuracy: 0.8883 - auc: 0.9590 - loss: 0.2428 - precision: 0.9002 - recall: 0.8735 - val_accuracy: 0.8526 - val_auc: 0.9292 - val_loss: 0.3509 - val_precision: 0.8706 - val_recall: 0.8283
# Epoch 38/50
# 3701/3701 - 33s - 9ms/step - accuracy: 0.8898 - auc: 0.9599 - loss: 0.2400 - precision: 0.9015 - recall: 0.8752 - val_accuracy: 0.8522 - val_auc: 0.9294 - val_loss: 0.3529 - val_precision: 0.8637 - val_recall: 0.8363
# Epoch 39/50
# 3701/3701 - 41s - 11ms/step - accuracy: 0.8911 - auc: 0.9609 - loss: 0.2371 - precision: 0.9032 - recall: 0.8760 - val_accuracy: 0.8544 - val_auc: 0.9302 - val_loss: 0.3507 - val_precision: 0.8663 - val_recall: 0.8380
# Epoch 40/50
# 3701/3701 - 32s - 9ms/step - accuracy: 0.8926 - auc: 0.9620 - loss: 0.2333 - precision: 0.9051 - recall: 0.8773 - val_accuracy: 0.8556 - val_auc: 0.9313 - val_loss: 0.3472 - val_precision: 0.8736 - val_recall: 0.8314
# Epoch 41/50
# 3701/3701 - 34s - 9ms/step - accuracy: 0.8935 - auc: 0.9625 - loss: 0.2320 - precision: 0.9056 - recall: 0.8786 - val_accuracy: 0.8553 - val_auc: 0.9311 - val_loss: 0.3432 - val_precision: 0.8729 - val_recall: 0.8318
# Epoch 42/50
# 3701/3701 - 32s - 9ms/step - accuracy: 0.8943 - auc: 0.9632 - loss: 0.2295 - precision: 0.9060 - recall: 0.8799 - val_accuracy: 0.8556 - val_auc: 0.9314 - val_loss: 0.3506 - val_precision: 0.8740 - val_recall: 0.8311
# Epoch 43/50
# 3701/3701 - 31s - 8ms/step - accuracy: 0.8950 - auc: 0.9639 - loss: 0.2274 - precision: 0.9069 - recall: 0.8803 - val_accuracy: 0.8582 - val_auc: 0.9320 - val_loss: 0.3470 - val_precision: 0.8709 - val_recall: 0.8412
# Epoch 44/50
# 3701/3701 - 33s - 9ms/step - accuracy: 0.8960 - auc: 0.9641 - loss: 0.2268 - precision: 0.9082 - recall: 0.8810 - val_accuracy: 0.8549 - val_auc: 0.9314 - val_loss: 0.3507 - val_precision: 0.8726 - val_recall: 0.8312
# Epoch 45/50
# 3701/3701 - 41s - 11ms/step - accuracy: 0.8988 - auc: 0.9653 - loss: 0.2222 - precision: 0.9101 - recall: 0.8849 - val_accuracy: 0.8573 - val_auc: 0.9317 - val_loss: 0.3490 - val_precision: 0.8732 - val_recall: 0.8359
# Epoch 46/50
# 3701/3701 - 35s - 9ms/step - accuracy: 0.8985 - auc: 0.9655 - loss: 0.2218 - precision: 0.9102 - recall: 0.8842 - val_accuracy: 0.8584 - val_auc: 0.9320 - val_loss: 0.3488 - val_precision: 0.8766 - val_recall: 0.8344
# Epoch 47/50
# 3701/3701 - 33s - 9ms/step - accuracy: 0.8986 - auc: 0.9659 - loss: 0.2205 - precision: 0.9102 - recall: 0.8844 - val_accuracy: 0.8583 - val_auc: 0.9331 - val_loss: 0.3498 - val_precision: 0.8718 - val_recall: 0.8401
# Epoch 48/50
# 3701/3701 - 33s - 9ms/step - accuracy: 0.9001 - auc: 0.9667 - loss: 0.2176 - precision: 0.9114 - recall: 0.8863 - val_accuracy: 0.8570 - val_auc: 0.9327 - val_loss: 0.3524 - val_precision: 0.8803 - val_recall: 0.8265
# Epoch 49/50
# 3701/3701 - 33s - 9ms/step - accuracy: 0.9012 - auc: 0.9670 - loss: 0.2167 - precision: 0.9131 - recall: 0.8868 - val_accuracy: 0.8580 - val_auc: 0.9334 - val_loss: 0.3470 - val_precision: 0.8708 - val_recall: 0.8408
# Epoch 50/50
# 3701/3701 - 33s - 9ms/step - accuracy: 0.9015 - auc: 0.9677 - loss: 0.2140 - precision: 0.9123 - recall: 0.8884 - val_accuracy: 0.8596 - val_auc: 0.9334 - val_loss: 0.3482 - val_precision: 0.8777 - val_recall: 0.8356

# %% [markdown]
# ### Predição e ajuste de limiar
#
# - **Predição:**
#   O modelo LSTM gera, para cada amostra de teste, uma probabilidade (`y_pred_prob`) de ser positivo (ter sepse). Essas probabilidades são valores contínuos entre 0 e 1.
#
# - **Ajuste de limiar:**
#   Para transformar as probabilidades em classes (0 ou 1), define-se um limiar (threshold), normalmente 0.5.
#   - Se a probabilidade for maior ou igual ao limiar, a previsão é positiva (1).
#   - Se for menor, a previsão é negativa (0).
#
# - **Importância:**
#   O ajuste do limiar pode ser alterado conforme a necessidade do problema, por exemplo, para aumentar o recall ou a precisão, dependendo do objetivo clinico

# %%
# Definir a forma da entrada (janelas, variáveis)
input_shape = X_train.shape[1:]  # (10, 8)

# Construir o modelo aprimorado
inputs = tf.keras.Input(shape=input_shape)

# A camada Masking é ótima para dados faltantes ou preenchidos com zero
x = layers.Masking(mask_value=0.0)(inputs)

# Camada Bidirecional para capturar contexto de ambas as direções
# return_sequences=True é necessário para empilhar com outra camada recorrente
x = layers.Bidirectional(layers.LSTM(64, return_sequences=True))(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.4)(x) # Aumentar um pouco o dropout para um modelo mais complexo

# Segunda camada LSTM para aprender padrões mais profundos
x = layers.Bidirectional(layers.LSTM(32, return_sequences=False))(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.4)(x)

# Camada densa para classificação final
x = layers.Dense(32)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)
x = layers.Dropout(0.5)(x) # Dropout final antes da camada de saída

outputs = layers.Dense(1, activation='sigmoid')(x)

model_lstm = models.Model(inputs, outputs)

# %% [markdown]
# ## Resultados

# %%
# Predição
y_pred_prob = model_lstm.predict(X_test).flatten()

# Ajustar limiar (exemplo: 0.5)
limiar = 0.5
y_pred = (y_pred_prob >= limiar).astype(int)

# Métricas
print(f"Acurácia: {accuracy_score(y_test, y_pred):.4f}")
print(f"AUC: {roc_auc_score(y_test, y_pred_prob):.4f}")
print(f"Precisão: {precision_score(y_test, y_pred):.4f}")
print(f"Revocação: {recall_score(y_test, y_pred):.4f}")
print(f"F1-score: {f1_score(y_test, y_pred):.4f}")

# Matriz de Confusão
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Sem Sepse", "Com Sepse"])
disp.plot(cmap='Blues')
plt.title("Matriz de Confusão - LSTM")
plt.show()
# Out:
# 1586/1586 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step
# Acurácia: 0.5098
# AUC: 0.5905
# Precisão: 0.5051
# Revocação: 0.9611
# F1-score: 0.6622

# %%
# Curva ROC
fpr, tpr, _ = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, label=f"ROC (AUC = {roc_auc:.2f})")
plt.plot([0, 1], [0, 1], 'k--', lw=1)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("Taxa de Falsos Positivos (FPR)")
plt.ylabel("Taxa de Verdadeiros Positivos (TPR)")
plt.title("Curva ROC - LSTM")
plt.legend(loc="lower right")
plt.grid(True)
plt.show()

# %%
# Curva Precision-Recall
precision, recall, _ = precision_recall_curve(y_test, y_pred_prob)
ap_score = average_precision_score(y_test, y_pred_prob)

plt.figure()
plt.plot(recall, precision, label=f"AP = {ap_score:.2f}")
plt.xlabel("Recall")
plt.ylabel("Precisão")
plt.title("Curva Precision-Recall - LSTM")
plt.legend(loc="lower left")
plt.grid(True)
plt.show()
