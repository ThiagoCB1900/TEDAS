# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.metrics import accuracy_score, roc_auc_score, precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay, roc_curve, auc, precision_recall_curve, average_precision_score
import matplotlib.pyplot as plt

# %% [markdown]
# ## Carregar e tratar a base

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler  # <-- Troca aqui
import joblib
import numpy as np


# Carregar os dados
data = np.load("mimic_X_y_mask_10j.npz")
X = data['X']
y = data['y']
mask = data['mask']

# Balanceamento
idx_sepse = np.where(y == 1)[0]
idx_nsepse = np.where(y == 0)[0]
n = min(len(idx_sepse), len(idx_nsepse))
idx_balanced = np.concatenate([idx_sepse[:n], idx_nsepse[:n]])
np.random.shuffle(idx_balanced)

X_bal = X[idx_balanced]
y_bal = y[idx_balanced]
mask_bal = mask[idx_balanced]

# Divisão treino/val/teste
from sklearn.model_selection import train_test_split

X_train, X_temp, y_train, y_temp, mask_train, mask_temp = train_test_split(
    X_bal, y_bal, mask_bal, test_size=0.30, random_state=42, stratify=y_bal)

X_val, X_test, y_val, y_test, mask_val, mask_test = train_test_split(
    X_temp, y_temp, mask_temp, test_size=0.50, random_state=42, stratify=y_temp)

# Normalização segura por feature
def normalize_split_data(X_train, X_val, X_test):
    n_samples, n_janelas, n_features = X_train.shape
    X_train_norm = np.zeros_like(X_train)
    X_val_norm = np.zeros_like(X_val)
    X_test_norm = np.zeros_like(X_test)
    scalers = []

    for i in range(n_features):
        scaler = StandardScaler()  # <-- Troca aqui
        # scaler = MinMaxScaler()
        feat_train = X_train[:, :, i].reshape(-1, 1)
        scaler.fit(feat_train)  # Ajusta SOMENTE no treino

        # Aplica a mesma escala
        X_train_norm[:, :, i] = scaler.transform(feat_train).reshape(n_samples, n_janelas)
        X_val_norm[:, :, i] = scaler.transform(X_val[:, :, i].reshape(-1, 1)).reshape(X_val.shape[0], n_janelas)
        X_test_norm[:, :, i] = scaler.transform(X_test[:, :, i].reshape(-1, 1)).reshape(X_test.shape[0], n_janelas)

        scalers.append(scaler)

    return X_train_norm, X_val_norm, X_test_norm, scalers

# Executar normalização
X_train_norm, X_val_norm, X_test_norm, scalers = normalize_split_data(X_train, X_val, X_test)

# Salvar scalers
joblib.dump(scalers, "scalers_standard_lstm.pkl")  # <-- Nome atualizado

# Atualizar variáveis do pipeline
X_train, X_val, X_test = X_train_norm, X_val_norm, X_test_norm

print("✅ Normalização segura concluída com StandardScaler e scalers salvos!")
# Out:
# ✅ Normalização segura concluída com StandardScaler e scalers salvos!

# %% [markdown]
# ## Carregar sem tratar a base (V.1)

# %% [markdown]
# ### Divisão dos dados em treino, validação e teste
#
# - **Objetivo:** Separar o conjunto balanceado em três partes: treino (70%), validação (15%) e teste (15%).
# - **Como:**
#   - Primeiro, separa 70% para treino e 30% para validação+teste.
#   - Depois, divide os 30% restantes igualmente entre validação e teste.
# - **Estratificação:** A divisão mantém a proporção das classes (sepse/não sepse) em todos os conjuntos.
# - **Importância:** Garante avaliação justa do modelo e evita vazamento de dados entre treino e teste.

# %% [markdown]
# ### Construção do modelo LSTM
#
# - **Definição da entrada:** O modelo recebe sequências no formato `(janelas, variáveis)` para cada paciente.
# - **Máscara:** A camada `Masking` faz o modelo ignorar posições preenchidas com zero (usadas para padding).
# - **LSTM:** Camada principal que processa as sequências temporais, capturando padrões ao longo do tempo.
# - **Dropout:** Ajuda a evitar overfitting, desligando aleatoriamente parte dos neurônios durante o treino.
# - **Dense:** Camada totalmente conectada para refinar a representação.
# - **Saída:** Camada final com ativação sigmoide para prever a probabilidade de sepse (0 ou 1).

# %% [markdown]
# ## LSTM

# %%
# Definir a forma da entrada (janelas, variáveis)
input_shape = X_train.shape[1:]  # (10, 8)

# Construir o modelo
inputs = tf.keras.Input(shape=input_shape)
x = layers.Masking(mask_value=0.0)(inputs)
x = layers.LSTM(64, return_sequences=False)(x)
x = layers.Dropout(0.3)(x)
x = layers.Dense(32, activation='relu')(x)
outputs = layers.Dense(1, activation='sigmoid')(x)

model_lstm = models.Model(inputs, outputs)

# %% [markdown]
# ### Compilação do modelo LSTM
#
# - **O que é feito:**
#   Esta célula configura como o modelo LSTM será treinado, definindo o otimizador, a função de perda e as métricas de avaliação.
#
# - **Parâmetros definidos:**
#   - **optimizer='adam':**
#     Utiliza o otimizador Adam, que é eficiente e amplamente usado em deep learning por ajustar automaticamente a taxa de aprendizado durante o treinamento.
#   - **loss='binary_crossentropy':**
#     Define a função de perda como entropia cruzada binária, adequada para problemas de classificação binária (sepse ou não).
#   - **metrics:**
#     Lista de métricas que serão monitoradas durante o treinamento e validação:
#     - **BinaryAccuracy (accuracy):** Mede a proporção de previsões corretas (acertos) entre as amostras.
#     - **AUC (Área sob a curva ROC):** Avalia a capacidade do modelo em distinguir entre as classes, considerando diferentes limiares de decisão.
#     - **Recall (Sensibilidade):** Mede a proporção de casos positivos corretamente identificados (importante para não perder casos de sepse).
#     - **Precision (Precisão):** Mede a proporção de previsões positivas que realmente são positivas (importante para evitar alarmes falsos).
#
# - **Resumo:**
#   Com essa configuração, o modelo será treinado de forma eficiente e avaliado por métricas que ajudam a entender não só o acerto geral, mas também a capacidade de identificar corretamente casos de sepse e evitar falsos positivos.

# %%
model_lstm.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=[
        tf.keras.metrics.BinaryAccuracy(name='accuracy'),
        tf.keras.metrics.AUC(name='auc'),
        tf.keras.metrics.Recall(name='recall'),
        tf.keras.metrics.Precision(name='precision')
    ]
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %% [markdown]
# ### Treinamento do modelo LSTM
#
# - **O que está sendo feito:**
#   Esta célula inicia o treinamento do modelo LSTM usando os dados de treino e validação.
#
# - **Parâmetros principais:**
#   - `X_train, y_train`: Dados de entrada e rótulos para o treinamento do modelo.
#   - `validation_data=(X_val, y_val)`: Dados separados para validação, permitindo monitorar o desempenho do modelo em dados não vistos durante o treino.
#   - `epochs=50`: O modelo será treinado por até 50 ciclos completos sobre o conjunto de treino. Um número maior de épocas pode ajudar o modelo a aprender melhor, mas também pode causar overfitting se exagerado.
#   - `batch_size=64`: O modelo atualiza os pesos a cada 64 amostras. Batches maiores podem acelerar o treinamento, mas exigem mais memória.
#   - `verbose=2`: Controla o nível de detalhamento dos logs durante o treinamento (2 mostra uma linha por época).
#
# - **Por que usar validação?**
#   O conjunto de validação serve para acompanhar se o modelo está realmente aprendendo padrões úteis ou apenas decorando os dados de treino (overfitting). Assim, é possível ajustar hiperparâmetros e escolher o melhor modelo.
#
# - **Resumo:**
#   Ao final desse processo, o histórico de treinamento (`history`) terá informações sobre a evolução das métricas de desempenho em treino e validação, permitindo avaliar e comparar os resultados.

# %%
# Treinamento do modelo
history = model_lstm.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=50,
    batch_size=64,
    verbose=2
)
# Out:
# Epoch 1/50
# 3701/3701 - 23s - 6ms/step - accuracy: 0.7003 - auc: 0.7697 - loss: 0.5733 - precision: 0.6942 - recall: 0.7159 - val_accuracy: 0.7129 - val_auc: 0.7874 - val_loss: 0.5556 - val_precision: 0.7204 - val_recall: 0.6959
# Epoch 2/50
# 3701/3701 - 20s - 6ms/step - accuracy: 0.7186 - auc: 0.7931 - loss: 0.5495 - precision: 0.7186 - recall: 0.7186 - val_accuracy: 0.7247 - val_auc: 0.8032 - val_loss: 0.5393 - val_precision: 0.7178 - val_recall: 0.7406
# Epoch 3/50
# 3701/3701 - 20s - 6ms/step - accuracy: 0.7303 - auc: 0.8079 - loss: 0.5330 - precision: 0.7323 - recall: 0.7260 - val_accuracy: 0.7358 - val_auc: 0.8159 - val_loss: 0.5236 - val_precision: 0.7368 - val_recall: 0.7339
# Epoch 4/50
# 3701/3701 - 21s - 6ms/step - accuracy: 0.7417 - auc: 0.8219 - loss: 0.5165 - precision: 0.7459 - recall: 0.7331 - val_accuracy: 0.7461 - val_auc: 0.8274 - val_loss: 0.5093 - val_precision: 0.7506 - val_recall: 0.7370
# Epoch 5/50
# 3701/3701 - 21s - 6ms/step - accuracy: 0.7536 - auc: 0.8343 - loss: 0.5011 - precision: 0.7586 - recall: 0.7438 - val_accuracy: 0.7558 - val_auc: 0.8394 - val_loss: 0.4950 - val_precision: 0.7497 - val_recall: 0.7682
# Epoch 6/50
# 3701/3701 - 21s - 6ms/step - accuracy: 0.7642 - auc: 0.8453 - loss: 0.4861 - precision: 0.7709 - recall: 0.7520 - val_accuracy: 0.7647 - val_auc: 0.8468 - val_loss: 0.4844 - val_precision: 0.7675 - val_recall: 0.7595
# Epoch 7/50
# 3701/3701 - 21s - 6ms/step - accuracy: 0.7717 - auc: 0.8543 - loss: 0.4733 - precision: 0.7786 - recall: 0.7594 - val_accuracy: 0.7704 - val_auc: 0.8536 - val_loss: 0.4744 - val_precision: 0.7739 - val_recall: 0.7641
# Epoch 8/50
# 3701/3701 - 21s - 6ms/step - accuracy: 0.7797 - auc: 0.8621 - loss: 0.4619 - precision: 0.7881 - recall: 0.7651 - val_accuracy: 0.7765 - val_auc: 0.8616 - val_loss: 0.4632 - val_precision: 0.7809 - val_recall: 0.7687
# Epoch 9/50
# 3701/3701 - 21s - 6ms/step - accuracy: 0.7874 - auc: 0.8694 - loss: 0.4507 - precision: 0.7966 - recall: 0.7719 - val_accuracy: 0.7824 - val_auc: 0.8660 - val_loss: 0.4557 - val_precision: 0.7926 - val_recall: 0.7651
# Epoch 10/50
# 3701/3701 - 21s - 6ms/step - accuracy: 0.7922 - auc: 0.8757 - loss: 0.4406 - precision: 0.8027 - recall: 0.7750 - val_accuracy: 0.7861 - val_auc: 0.8687 - val_loss: 0.4518 - val_precision: 0.7916 - val_recall: 0.7767
# Epoch 11/50
# 3701/3701 - 21s - 6ms/step - accuracy: 0.7976 - auc: 0.8806 - loss: 0.4326 - precision: 0.8078 - recall: 0.7810 - val_accuracy: 0.7908 - val_auc: 0.8751 - val_loss: 0.4413 - val_precision: 0.7954 - val_recall: 0.7831
# Epoch 12/50
# 3701/3701 - 21s - 6ms/step - accuracy: 0.8030 - auc: 0.8861 - loss: 0.4231 - precision: 0.8126 - recall: 0.7875 - val_accuracy: 0.7947 - val_auc: 0.8788 - val_loss: 0.4372 - val_precision: 0.8185 - val_recall: 0.7574
# Epoch 13/50
# 3701/3701 - 21s - 6ms/step - accuracy: 0.8074 - auc: 0.8907 - loss: 0.4155 - precision: 0.8181 - recall: 0.7907 - val_accuracy: 0.7975 - val_auc: 0.8815 - val_loss: 0.4322 - val_precision: 0.8157 - val_recall: 0.7686
# Epoch 14/50
# 3701/3701 - 22s - 6ms/step - accuracy: 0.8115 - auc: 0.8948 - loss: 0.4079 - precision: 0.8220 - recall: 0.7953 - val_accuracy: 0.8015 - val_auc: 0.8851 - val_loss: 0.4248 - val_precision: 0.8060 - val_recall: 0.7942
# Epoch 15/50
# 3701/3701 - 21s - 6ms/step - accuracy: 0.8160 - auc: 0.8989 - loss: 0.4004 - precision: 0.8271 - recall: 0.7990 - val_accuracy: 0.8054 - val_auc: 0.8879 - val_loss: 0.4209 - val_precision: 0.8104 - val_recall: 0.7974
# Epoch 16/50
# 3701/3701 - 23s - 6ms/step - accuracy: 0.8202 - auc: 0.9026 - loss: 0.3936 - precision: 0.8318 - recall: 0.8027 - val_accuracy: 0.8054 - val_auc: 0.8897 - val_loss: 0.4169 - val_precision: 0.8103 - val_recall: 0.7974
# Epoch 17/50
# 3701/3701 - 23s - 6ms/step - accuracy: 0.8232 - auc: 0.9053 - loss: 0.3885 - precision: 0.8353 - recall: 0.8051 - val_accuracy: 0.8073 - val_auc: 0.8917 - val_loss: 0.4142 - val_precision: 0.8288 - val_recall: 0.7746
# Epoch 18/50
# 3701/3701 - 22s - 6ms/step - accuracy: 0.8266 - auc: 0.9081 - loss: 0.3829 - precision: 0.8375 - recall: 0.8105 - val_accuracy: 0.8098 - val_auc: 0.8942 - val_loss: 0.4093 - val_precision: 0.8321 - val_recall: 0.7763
# Epoch 19/50
# 3701/3701 - 22s - 6ms/step - accuracy: 0.8299 - auc: 0.9111 - loss: 0.3768 - precision: 0.8417 - recall: 0.8126 - val_accuracy: 0.8147 - val_auc: 0.8972 - val_loss: 0.4038 - val_precision: 0.8286 - val_recall: 0.7935
# Epoch 20/50
# 3701/3701 - 23s - 6ms/step - accuracy: 0.8327 - auc: 0.9136 - loss: 0.3719 - precision: 0.8454 - recall: 0.8142 - val_accuracy: 0.8142 - val_auc: 0.8967 - val_loss: 0.4062 - val_precision: 0.8336 - val_recall: 0.7851
# Epoch 21/50
# 3701/3701 - 24s - 7ms/step - accuracy: 0.8351 - auc: 0.9158 - loss: 0.3673 - precision: 0.8479 - recall: 0.8168 - val_accuracy: 0.8174 - val_auc: 0.8994 - val_loss: 0.4036 - val_precision: 0.8418 - val_recall: 0.7817
# Epoch 22/50
# 3701/3701 - 24s - 7ms/step - accuracy: 0.8365 - auc: 0.9176 - loss: 0.3635 - precision: 0.8497 - recall: 0.8177 - val_accuracy: 0.8202 - val_auc: 0.9014 - val_loss: 0.3968 - val_precision: 0.8302 - val_recall: 0.8052
# Epoch 23/50
# 3701/3701 - 24s - 7ms/step - accuracy: 0.8395 - auc: 0.9195 - loss: 0.3597 - precision: 0.8517 - recall: 0.8220 - val_accuracy: 0.8194 - val_auc: 0.9014 - val_loss: 0.3992 - val_precision: 0.8259 - val_recall: 0.8094
# Epoch 24/50
# 3701/3701 - 24s - 7ms/step - accuracy: 0.8415 - auc: 0.9213 - loss: 0.3556 - precision: 0.8545 - recall: 0.8232 - val_accuracy: 0.8198 - val_auc: 0.9024 - val_loss: 0.3954 - val_precision: 0.8390 - val_recall: 0.7916
# Epoch 25/50
# 3701/3701 - 24s - 7ms/step - accuracy: 0.8426 - auc: 0.9225 - loss: 0.3527 - precision: 0.8555 - recall: 0.8246 - val_accuracy: 0.8228 - val_auc: 0.9036 - val_loss: 0.3939 - val_precision: 0.8371 - val_recall: 0.8017
# Epoch 26/50
# 3701/3701 - 24s - 7ms/step - accuracy: 0.8454 - auc: 0.9243 - loss: 0.3490 - precision: 0.8588 - recall: 0.8269 - val_accuracy: 0.8250 - val_auc: 0.9053 - val_loss: 0.3900 - val_precision: 0.8437 - val_recall: 0.7978
# Epoch 27/50
# 3701/3701 - 25s - 7ms/step - accuracy: 0.8465 - auc: 0.9259 - loss: 0.3454 - precision: 0.8595 - recall: 0.8285 - val_accuracy: 0.8220 - val_auc: 0.9044 - val_loss: 0.3916 - val_precision: 0.8488 - val_recall: 0.7834
# Epoch 28/50
# 3701/3701 - 24s - 6ms/step - accuracy: 0.8489 - auc: 0.9274 - loss: 0.3422 - precision: 0.8618 - recall: 0.8310 - val_accuracy: 0.8267 - val_auc: 0.9058 - val_loss: 0.3902 - val_precision: 0.8401 - val_recall: 0.8072
# Epoch 29/50
# 3701/3701 - 25s - 7ms/step - accuracy: 0.8512 - auc: 0.9290 - loss: 0.3383 - precision: 0.8637 - recall: 0.8340 - val_accuracy: 0.8295 - val_auc: 0.9080 - val_loss: 0.3861 - val_precision: 0.8520 - val_recall: 0.7977
# Epoch 30/50
# 3701/3701 - 26s - 7ms/step - accuracy: 0.8515 - auc: 0.9297 - loss: 0.3368 - precision: 0.8648 - recall: 0.8332 - val_accuracy: 0.8285 - val_auc: 0.9080 - val_loss: 0.3859 - val_precision: 0.8413 - val_recall: 0.8098
# Epoch 31/50
# 3701/3701 - 27s - 7ms/step - accuracy: 0.8534 - auc: 0.9311 - loss: 0.3335 - precision: 0.8663 - recall: 0.8358 - val_accuracy: 0.8297 - val_auc: 0.9096 - val_loss: 0.3823 - val_precision: 0.8439 - val_recall: 0.8090
# Epoch 32/50
# 3701/3701 - 25s - 7ms/step - accuracy: 0.8551 - auc: 0.9323 - loss: 0.3309 - precision: 0.8679 - recall: 0.8376 - val_accuracy: 0.8296 - val_auc: 0.9092 - val_loss: 0.3838 - val_precision: 0.8433 - val_recall: 0.8096
# Epoch 33/50
# 3701/3701 - 24s - 7ms/step - accuracy: 0.8554 - auc: 0.9330 - loss: 0.3291 - precision: 0.8683 - recall: 0.8379 - val_accuracy: 0.8333 - val_auc: 0.9111 - val_loss: 0.3794 - val_precision: 0.8443 - val_recall: 0.8172
# Epoch 34/50
# 3701/3701 - 24s - 7ms/step - accuracy: 0.8574 - auc: 0.9345 - loss: 0.3255 - precision: 0.8705 - recall: 0.8396 - val_accuracy: 0.8312 - val_auc: 0.9108 - val_loss: 0.3821 - val_precision: 0.8537 - val_recall: 0.7994
# Epoch 35/50
# 3701/3701 - 24s - 7ms/step - accuracy: 0.8583 - auc: 0.9353 - loss: 0.3235 - precision: 0.8711 - recall: 0.8412 - val_accuracy: 0.8332 - val_auc: 0.9113 - val_loss: 0.3801 - val_precision: 0.8479 - val_recall: 0.8121
# Epoch 36/50
# 3701/3701 - 24s - 7ms/step - accuracy: 0.8597 - auc: 0.9362 - loss: 0.3212 - precision: 0.8725 - recall: 0.8423 - val_accuracy: 0.8310 - val_auc: 0.9115 - val_loss: 0.3799 - val_precision: 0.8316 - val_recall: 0.8301
# Epoch 37/50
# 3701/3701 - 24s - 7ms/step - accuracy: 0.8611 - auc: 0.9367 - loss: 0.3200 - precision: 0.8747 - recall: 0.8429 - val_accuracy: 0.8349 - val_auc: 0.9130 - val_loss: 0.3759 - val_precision: 0.8482 - val_recall: 0.8157
# Epoch 38/50
# 3701/3701 - 24s - 7ms/step - accuracy: 0.8620 - auc: 0.9377 - loss: 0.3175 - precision: 0.8750 - recall: 0.8447 - val_accuracy: 0.8330 - val_auc: 0.9123 - val_loss: 0.3824 - val_precision: 0.8380 - val_recall: 0.8256
# Epoch 39/50
# 3701/3701 - 25s - 7ms/step - accuracy: 0.8622 - auc: 0.9383 - loss: 0.3160 - precision: 0.8757 - recall: 0.8443 - val_accuracy: 0.8328 - val_auc: 0.9112 - val_loss: 0.3848 - val_precision: 0.8478 - val_recall: 0.8112
# Epoch 40/50
# 3701/3701 - 24s - 7ms/step - accuracy: 0.8641 - auc: 0.9392 - loss: 0.3140 - precision: 0.8776 - recall: 0.8462 - val_accuracy: 0.8354 - val_auc: 0.9135 - val_loss: 0.3749 - val_precision: 0.8425 - val_recall: 0.8250
# Epoch 41/50
# 3701/3701 - 25s - 7ms/step - accuracy: 0.8650 - auc: 0.9399 - loss: 0.3121 - precision: 0.8789 - recall: 0.8467 - val_accuracy: 0.8356 - val_auc: 0.9144 - val_loss: 0.3744 - val_precision: 0.8463 - val_recall: 0.8201
# Epoch 42/50
# 3701/3701 - 24s - 7ms/step - accuracy: 0.8661 - auc: 0.9408 - loss: 0.3098 - precision: 0.8787 - recall: 0.8493 - val_accuracy: 0.8341 - val_auc: 0.9123 - val_loss: 0.3800 - val_precision: 0.8528 - val_recall: 0.8077
# Epoch 43/50
# 3701/3701 - 24s - 7ms/step - accuracy: 0.8671 - auc: 0.9412 - loss: 0.3088 - precision: 0.8796 - recall: 0.8505 - val_accuracy: 0.8359 - val_auc: 0.9160 - val_loss: 0.3700 - val_precision: 0.8540 - val_recall: 0.8104
# Epoch 44/50
# 3701/3701 - 24s - 7ms/step - accuracy: 0.8670 - auc: 0.9414 - loss: 0.3082 - precision: 0.8811 - recall: 0.8486 - val_accuracy: 0.8361 - val_auc: 0.9155 - val_loss: 0.3716 - val_precision: 0.8436 - val_recall: 0.8251
# Epoch 45/50
# 3701/3701 - 24s - 7ms/step - accuracy: 0.8686 - auc: 0.9427 - loss: 0.3047 - precision: 0.8820 - recall: 0.8509 - val_accuracy: 0.8367 - val_auc: 0.9149 - val_loss: 0.3766 - val_precision: 0.8505 - val_recall: 0.8170
# Epoch 46/50
# 3701/3701 - 24s - 7ms/step - accuracy: 0.8690 - auc: 0.9428 - loss: 0.3043 - precision: 0.8826 - recall: 0.8513 - val_accuracy: 0.8400 - val_auc: 0.9176 - val_loss: 0.3692 - val_precision: 0.8528 - val_recall: 0.8219
# Epoch 47/50
# 3701/3701 - 25s - 7ms/step - accuracy: 0.8710 - auc: 0.9444 - loss: 0.3003 - precision: 0.8843 - recall: 0.8537 - val_accuracy: 0.8397 - val_auc: 0.9165 - val_loss: 0.3707 - val_precision: 0.8564 - val_recall: 0.8162
# Epoch 48/50
# 3701/3701 - 25s - 7ms/step - accuracy: 0.8712 - auc: 0.9444 - loss: 0.3003 - precision: 0.8847 - recall: 0.8536 - val_accuracy: 0.8392 - val_auc: 0.9157 - val_loss: 0.3727 - val_precision: 0.8552 - val_recall: 0.8166
# Epoch 49/50
# 3701/3701 - 25s - 7ms/step - accuracy: 0.8714 - auc: 0.9449 - loss: 0.2987 - precision: 0.8852 - recall: 0.8536 - val_accuracy: 0.8403 - val_auc: 0.9166 - val_loss: 0.3709 - val_precision: 0.8536 - val_recall: 0.8214
# Epoch 50/50
# 3701/3701 - 24s - 7ms/step - accuracy: 0.8716 - auc: 0.9453 - loss: 0.2976 - precision: 0.8849 - recall: 0.8544 - val_accuracy: 0.8357 - val_auc: 0.9149 - val_loss: 0.3786 - val_precision: 0.8690 - val_recall: 0.7906

# %%
input_shape = X_train.shape[1:]  # alternativo

inputs = tf.keras.Input(shape=input_shape)
x = layers.Masking(mask_value=0.0)(inputs)
x = layers.Bidirectional(layers.LSTM(64, return_sequences=True))(x)
x = layers.GlobalAveragePooling1D()(x)
x = layers.Dropout(0.2)(x)
x = layers.Dense(32, activation='relu')(x)
outputs = layers.Dense(1, activation='sigmoid')(x)

model_lstm = tf.keras.Model(inputs, outputs)
model_lstm.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=[
        tf.keras.metrics.BinaryAccuracy(name='accuracy'),
        tf.keras.metrics.AUC(name='auc'),
        tf.keras.metrics.Recall(name='recall'),
        tf.keras.metrics.Precision(name='precision')
    ]
)

# Opcional: sample_weight por quantidade de janelas válidas
sample_weights = mask_train.sum(axis=1) / mask_train.shape[1]

# Treinamento
model_lstm.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=50,
    batch_size=64,
    sample_weight=sample_weights,
    verbose=2
)
# Out:
# Epoch 1/50
# 3701/3701 - 37s - 10ms/step - accuracy: 0.7025 - auc: 0.7732 - loss: 0.5541 - precision: 0.6965 - recall: 0.7178 - val_accuracy: 0.7170 - val_auc: 0.7940 - val_loss: 0.5485 - val_precision: 0.7045 - val_recall: 0.7474
# Epoch 2/50
# 3701/3701 - 33s - 9ms/step - accuracy: 0.7246 - auc: 0.8006 - loss: 0.5258 - precision: 0.7229 - recall: 0.7283 - val_accuracy: 0.7344 - val_auc: 0.8138 - val_loss: 0.5255 - val_precision: 0.7364 - val_recall: 0.7301
# Epoch 3/50
# 3701/3701 - 33s - 9ms/step - accuracy: 0.7412 - auc: 0.8196 - loss: 0.5042 - precision: 0.7427 - recall: 0.7380 - val_accuracy: 0.7489 - val_auc: 0.8299 - val_loss: 0.5064 - val_precision: 0.7523 - val_recall: 0.7422
# Epoch 4/50
# 3701/3701 - 33s - 9ms/step - accuracy: 0.7549 - auc: 0.8353 - loss: 0.4844 - precision: 0.7584 - recall: 0.7480 - val_accuracy: 0.7598 - val_auc: 0.8417 - val_loss: 0.4912 - val_precision: 0.7582 - val_recall: 0.7628
# Epoch 5/50
# 3701/3701 - 33s - 9ms/step - accuracy: 0.7665 - auc: 0.8488 - loss: 0.4661 - precision: 0.7718 - recall: 0.7567 - val_accuracy: 0.7725 - val_auc: 0.8557 - val_loss: 0.4711 - val_precision: 0.7877 - val_recall: 0.7461
# Epoch 6/50
# 3701/3701 - 34s - 9ms/step - accuracy: 0.7784 - auc: 0.8607 - loss: 0.4489 - precision: 0.7856 - recall: 0.7658 - val_accuracy: 0.7795 - val_auc: 0.8645 - val_loss: 0.4587 - val_precision: 0.8005 - val_recall: 0.7446
# Epoch 7/50
# 3701/3701 - 40s - 11ms/step - accuracy: 0.7886 - auc: 0.8716 - loss: 0.4324 - precision: 0.7969 - recall: 0.7746 - val_accuracy: 0.7891 - val_auc: 0.8728 - val_loss: 0.4457 - val_precision: 0.7984 - val_recall: 0.7736
# Epoch 8/50
# 3701/3701 - 42s - 11ms/step - accuracy: 0.7971 - auc: 0.8802 - loss: 0.4183 - precision: 0.8066 - recall: 0.7816 - val_accuracy: 0.7947 - val_auc: 0.8780 - val_loss: 0.4371 - val_precision: 0.8127 - val_recall: 0.7658
# Epoch 9/50
# 3701/3701 - 37s - 10ms/step - accuracy: 0.8042 - auc: 0.8879 - loss: 0.4051 - precision: 0.8152 - recall: 0.7869 - val_accuracy: 0.8004 - val_auc: 0.8840 - val_loss: 0.4275 - val_precision: 0.8048 - val_recall: 0.7932
# Epoch 10/50
# 3701/3701 - 33s - 9ms/step - accuracy: 0.8115 - auc: 0.8949 - loss: 0.3929 - precision: 0.8225 - recall: 0.7944 - val_accuracy: 0.8033 - val_auc: 0.8869 - val_loss: 0.4223 - val_precision: 0.8199 - val_recall: 0.7773
# Epoch 11/50
# 3701/3701 - 32s - 9ms/step - accuracy: 0.8179 - auc: 0.9008 - loss: 0.3819 - precision: 0.8289 - recall: 0.8013 - val_accuracy: 0.8116 - val_auc: 0.8949 - val_loss: 0.4073 - val_precision: 0.8270 - val_recall: 0.7880
# Epoch 12/50
# 3701/3701 - 34s - 9ms/step - accuracy: 0.8228 - auc: 0.9056 - loss: 0.3725 - precision: 0.8342 - recall: 0.8056 - val_accuracy: 0.8121 - val_auc: 0.8966 - val_loss: 0.4062 - val_precision: 0.8179 - val_recall: 0.8031
# Epoch 13/50
# 3701/3701 - 31s - 8ms/step - accuracy: 0.8278 - auc: 0.9106 - loss: 0.3631 - precision: 0.8396 - recall: 0.8106 - val_accuracy: 0.8171 - val_auc: 0.8995 - val_loss: 0.3996 - val_precision: 0.8313 - val_recall: 0.7957
# Epoch 14/50
# 3701/3701 - 32s - 9ms/step - accuracy: 0.8325 - auc: 0.9146 - loss: 0.3547 - precision: 0.8451 - recall: 0.8143 - val_accuracy: 0.8189 - val_auc: 0.9035 - val_loss: 0.3944 - val_precision: 0.8450 - val_recall: 0.7810
# Epoch 15/50
# 3701/3701 - 32s - 9ms/step - accuracy: 0.8375 - auc: 0.9186 - loss: 0.3465 - precision: 0.8498 - recall: 0.8200 - val_accuracy: 0.8211 - val_auc: 0.9043 - val_loss: 0.3911 - val_precision: 0.8335 - val_recall: 0.8026
# Epoch 16/50
# 3701/3701 - 34s - 9ms/step - accuracy: 0.8412 - auc: 0.9221 - loss: 0.3389 - precision: 0.8541 - recall: 0.8231 - val_accuracy: 0.8249 - val_auc: 0.9080 - val_loss: 0.3850 - val_precision: 0.8372 - val_recall: 0.8066
# Epoch 17/50
# 3701/3701 - 40s - 11ms/step - accuracy: 0.8452 - auc: 0.9255 - loss: 0.3314 - precision: 0.8581 - recall: 0.8271 - val_accuracy: 0.8267 - val_auc: 0.9082 - val_loss: 0.3854 - val_precision: 0.8410 - val_recall: 0.8056
# Epoch 18/50
# 3701/3701 - 41s - 11ms/step - accuracy: 0.8482 - auc: 0.9285 - loss: 0.3245 - precision: 0.8614 - recall: 0.8299 - val_accuracy: 0.8305 - val_auc: 0.9116 - val_loss: 0.3775 - val_precision: 0.8444 - val_recall: 0.8105
# Epoch 19/50
# 3701/3701 - 29s - 8ms/step - accuracy: 0.8526 - auc: 0.9316 - loss: 0.3172 - precision: 0.8658 - recall: 0.8345 - val_accuracy: 0.8330 - val_auc: 0.9140 - val_loss: 0.3735 - val_precision: 0.8467 - val_recall: 0.8132
# Epoch 20/50
# 3701/3701 - 33s - 9ms/step - accuracy: 0.8548 - auc: 0.9337 - loss: 0.3121 - precision: 0.8680 - recall: 0.8369 - val_accuracy: 0.8347 - val_auc: 0.9146 - val_loss: 0.3749 - val_precision: 0.8516 - val_recall: 0.8106
# Epoch 21/50
# 3701/3701 - 34s - 9ms/step - accuracy: 0.8579 - auc: 0.9363 - loss: 0.3062 - precision: 0.8709 - recall: 0.8403 - val_accuracy: 0.8373 - val_auc: 0.9166 - val_loss: 0.3708 - val_precision: 0.8555 - val_recall: 0.8118
# Epoch 22/50
# 3701/3701 - 33s - 9ms/step - accuracy: 0.8605 - auc: 0.9383 - loss: 0.3007 - precision: 0.8736 - recall: 0.8430 - val_accuracy: 0.8365 - val_auc: 0.9162 - val_loss: 0.3711 - val_precision: 0.8419 - val_recall: 0.8287
# Epoch 23/50
# 3701/3701 - 33s - 9ms/step - accuracy: 0.8633 - auc: 0.9401 - loss: 0.2964 - precision: 0.8761 - recall: 0.8462 - val_accuracy: 0.8411 - val_auc: 0.9193 - val_loss: 0.3652 - val_precision: 0.8487 - val_recall: 0.8301
# Epoch 24/50
# 3701/3701 - 33s - 9ms/step - accuracy: 0.8662 - auc: 0.9422 - loss: 0.2909 - precision: 0.8798 - recall: 0.8483 - val_accuracy: 0.8391 - val_auc: 0.9199 - val_loss: 0.3654 - val_precision: 0.8642 - val_recall: 0.8047
# Epoch 25/50
# 3701/3701 - 31s - 8ms/step - accuracy: 0.8682 - auc: 0.9439 - loss: 0.2865 - precision: 0.8818 - recall: 0.8503 - val_accuracy: 0.8428 - val_auc: 0.9212 - val_loss: 0.3585 - val_precision: 0.8554 - val_recall: 0.8252
# Epoch 26/50
# 3701/3701 - 25s - 7ms/step - accuracy: 0.8702 - auc: 0.9457 - loss: 0.2818 - precision: 0.8834 - recall: 0.8530 - val_accuracy: 0.8421 - val_auc: 0.9217 - val_loss: 0.3628 - val_precision: 0.8500 - val_recall: 0.8309
# Epoch 27/50
# 3701/3701 - 24s - 6ms/step - accuracy: 0.8734 - auc: 0.9471 - loss: 0.2782 - precision: 0.8863 - recall: 0.8566 - val_accuracy: 0.8454 - val_auc: 0.9228 - val_loss: 0.3562 - val_precision: 0.8571 - val_recall: 0.8292
# Epoch 28/50
# 3701/3701 - 24s - 6ms/step - accuracy: 0.8736 - auc: 0.9487 - loss: 0.2739 - precision: 0.8867 - recall: 0.8567 - val_accuracy: 0.8473 - val_auc: 0.9241 - val_loss: 0.3569 - val_precision: 0.8552 - val_recall: 0.8361
# Epoch 29/50
# 3701/3701 - 24s - 6ms/step - accuracy: 0.8767 - auc: 0.9500 - loss: 0.2702 - precision: 0.8903 - recall: 0.8592 - val_accuracy: 0.8468 - val_auc: 0.9250 - val_loss: 0.3554 - val_precision: 0.8709 - val_recall: 0.8144
# Epoch 30/50
# 3701/3701 - 24s - 6ms/step - accuracy: 0.8780 - auc: 0.9516 - loss: 0.2656 - precision: 0.8911 - recall: 0.8614 - val_accuracy: 0.8467 - val_auc: 0.9247 - val_loss: 0.3537 - val_precision: 0.8620 - val_recall: 0.8256
# Epoch 31/50
# 3701/3701 - 24s - 6ms/step - accuracy: 0.8799 - auc: 0.9527 - loss: 0.2624 - precision: 0.8931 - recall: 0.8631 - val_accuracy: 0.8478 - val_auc: 0.9257 - val_loss: 0.3549 - val_precision: 0.8660 - val_recall: 0.8229
# Epoch 32/50
# 3701/3701 - 24s - 6ms/step - accuracy: 0.8815 - auc: 0.9539 - loss: 0.2588 - precision: 0.8948 - recall: 0.8648 - val_accuracy: 0.8499 - val_auc: 0.9273 - val_loss: 0.3490 - val_precision: 0.8675 - val_recall: 0.8259
# Epoch 33/50
# 3701/3701 - 24s - 6ms/step - accuracy: 0.8830 - auc: 0.9548 - loss: 0.2561 - precision: 0.8964 - recall: 0.8661 - val_accuracy: 0.8496 - val_auc: 0.9266 - val_loss: 0.3564 - val_precision: 0.8596 - val_recall: 0.8356
# Epoch 34/50
# 3701/3701 - 24s - 6ms/step - accuracy: 0.8848 - auc: 0.9560 - loss: 0.2524 - precision: 0.8974 - recall: 0.8690 - val_accuracy: 0.8520 - val_auc: 0.9277 - val_loss: 0.3490 - val_precision: 0.8668 - val_recall: 0.8319
# Epoch 35/50
# 3701/3701 - 24s - 6ms/step - accuracy: 0.8864 - auc: 0.9570 - loss: 0.2497 - precision: 0.8996 - recall: 0.8700 - val_accuracy: 0.8509 - val_auc: 0.9281 - val_loss: 0.3497 - val_precision: 0.8716 - val_recall: 0.8231
# Epoch 36/50
# 3701/3701 - 24s - 6ms/step - accuracy: 0.8869 - auc: 0.9579 - loss: 0.2466 - precision: 0.8996 - recall: 0.8709 - val_accuracy: 0.8530 - val_auc: 0.9283 - val_loss: 0.3512 - val_precision: 0.8683 - val_recall: 0.8323
# Epoch 37/50
# 3701/3701 - 24s - 7ms/step - accuracy: 0.8897 - auc: 0.9591 - loss: 0.2434 - precision: 0.9024 - recall: 0.8739 - val_accuracy: 0.8539 - val_auc: 0.9304 - val_loss: 0.3465 - val_precision: 0.8640 - val_recall: 0.8400
# Epoch 38/50
# 3701/3701 - 24s - 7ms/step - accuracy: 0.8912 - auc: 0.9602 - loss: 0.2397 - precision: 0.9035 - recall: 0.8758 - val_accuracy: 0.8526 - val_auc: 0.9300 - val_loss: 0.3513 - val_precision: 0.8552 - val_recall: 0.8489
# Epoch 39/50
# 3701/3701 - 24s - 7ms/step - accuracy: 0.8914 - auc: 0.9609 - loss: 0.2376 - precision: 0.9039 - recall: 0.8759 - val_accuracy: 0.8542 - val_auc: 0.9301 - val_loss: 0.3479 - val_precision: 0.8695 - val_recall: 0.8335
# Epoch 40/50
# 3701/3701 - 24s - 7ms/step - accuracy: 0.8932 - auc: 0.9615 - loss: 0.2358 - precision: 0.9054 - recall: 0.8781 - val_accuracy: 0.8551 - val_auc: 0.9303 - val_loss: 0.3481 - val_precision: 0.8635 - val_recall: 0.8435
# Epoch 41/50
# 3701/3701 - 24s - 6ms/step - accuracy: 0.8936 - auc: 0.9622 - loss: 0.2331 - precision: 0.9058 - recall: 0.8785 - val_accuracy: 0.8541 - val_auc: 0.9300 - val_loss: 0.3482 - val_precision: 0.8616 - val_recall: 0.8437
# Epoch 42/50
# 3701/3701 - 27s - 7ms/step - accuracy: 0.8951 - auc: 0.9632 - loss: 0.2299 - precision: 0.9072 - recall: 0.8803 - val_accuracy: 0.8525 - val_auc: 0.9293 - val_loss: 0.3511 - val_precision: 0.8696 - val_recall: 0.8294
# Epoch 43/50
# 3701/3701 - 32s - 9ms/step - accuracy: 0.8955 - auc: 0.9634 - loss: 0.2291 - precision: 0.9076 - recall: 0.8807 - val_accuracy: 0.8552 - val_auc: 0.9310 - val_loss: 0.3508 - val_precision: 0.8616 - val_recall: 0.8464
# Epoch 44/50
# 3701/3701 - 32s - 9ms/step - accuracy: 0.8971 - auc: 0.9644 - loss: 0.2259 - precision: 0.9094 - recall: 0.8820 - val_accuracy: 0.8552 - val_auc: 0.9306 - val_loss: 0.3527 - val_precision: 0.8662 - val_recall: 0.8401
# Epoch 45/50
# 3701/3701 - 27s - 7ms/step - accuracy: 0.8983 - auc: 0.9653 - loss: 0.2231 - precision: 0.9105 - recall: 0.8835 - val_accuracy: 0.8551 - val_auc: 0.9308 - val_loss: 0.3497 - val_precision: 0.8655 - val_recall: 0.8409
# Epoch 46/50
# 3701/3701 - 40s - 11ms/step - accuracy: 0.8985 - auc: 0.9655 - loss: 0.2220 - precision: 0.9106 - recall: 0.8838 - val_accuracy: 0.8572 - val_auc: 0.9332 - val_loss: 0.3457 - val_precision: 0.8596 - val_recall: 0.8540
# Epoch 47/50
# 3701/3701 - 38s - 10ms/step - accuracy: 0.8998 - auc: 0.9662 - loss: 0.2196 - precision: 0.9119 - recall: 0.8851 - val_accuracy: 0.8561 - val_auc: 0.9322 - val_loss: 0.3465 - val_precision: 0.8646 - val_recall: 0.8443
# Epoch 48/50
# 3701/3701 - 24s - 6ms/step - accuracy: 0.9011 - auc: 0.9669 - loss: 0.2176 - precision: 0.9125 - recall: 0.8872 - val_accuracy: 0.8573 - val_auc: 0.9327 - val_loss: 0.3507 - val_precision: 0.8705 - val_recall: 0.8394
# Epoch 49/50
# 3701/3701 - 24s - 6ms/step - accuracy: 0.9013 - auc: 0.9672 - loss: 0.2164 - precision: 0.9129 - recall: 0.8873 - val_accuracy: 0.8593 - val_auc: 0.9333 - val_loss: 0.3500 - val_precision: 0.8644 - val_recall: 0.8524
# Epoch 50/50
# 3701/3701 - 24s - 7ms/step - accuracy: 0.9022 - auc: 0.9678 - loss: 0.2143 - precision: 0.9134 - recall: 0.8888 - val_accuracy: 0.8590 - val_auc: 0.9331 - val_loss: 0.3492 - val_precision: 0.8684 - val_recall: 0.8464

# %% [markdown]
# ### Predição e ajuste de limiar
#
# - **Predição:**
#   O modelo LSTM gera, para cada amostra de teste, uma probabilidade (`y_pred_prob`) de ser positivo (ter sepse). Essas probabilidades são valores contínuos entre 0 e 1.
#
# - **Ajuste de limiar:**
#   Para transformar as probabilidades em classes (0 ou 1), define-se um limiar (threshold), normalmente 0.5.
#   - Se a probabilidade for maior ou igual ao limiar, a previsão é positiva (1).
#   - Se for menor, a previsão é negativa (0).
#
# - **Importância:**
#   O ajuste do limiar pode ser alterado conforme a necessidade do problema, por exemplo, para aumentar o recall ou a precisão, dependendo do objetivo clinico

# %%
# Definir a forma da entrada (janelas, variáveis)
input_shape = X_train.shape[1:]  # (10, 8)

# Construir o modelo aprimorado
inputs = tf.keras.Input(shape=input_shape)

# A camada Masking é ótima para dados faltantes ou preenchidos com zero
x = layers.Masking(mask_value=0.0)(inputs)

# Camada Bidirecional para capturar contexto de ambas as direções
# return_sequences=True é necessário para empilhar com outra camada recorrente
x = layers.Bidirectional(layers.LSTM(64, return_sequences=True))(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.4)(x) # Aumentar um pouco o dropout para um modelo mais complexo

# Segunda camada LSTM para aprender padrões mais profundos
x = layers.Bidirectional(layers.LSTM(32, return_sequences=False))(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.4)(x)

# Camada densa para classificação final
x = layers.Dense(32)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)
x = layers.Dropout(0.5)(x) # Dropout final antes da camada de saída

outputs = layers.Dense(1, activation='sigmoid')(x)

model_lstm = models.Model(inputs, outputs)

# %% [markdown]
# ## Resultados

# %%
# Predição
y_pred_prob = model_lstm.predict(X_test).flatten()

# Ajustar limiar (exemplo: 0.5)
limiar = 0.5
y_pred = (y_pred_prob >= limiar).astype(int)

# Métricas
print(f"Acurácia: {accuracy_score(y_test, y_pred):.4f}")
print(f"AUC: {roc_auc_score(y_test, y_pred_prob):.4f}")
print(f"Precisão: {precision_score(y_test, y_pred):.4f}")
print(f"Revocação: {recall_score(y_test, y_pred):.4f}")
print(f"F1-score: {f1_score(y_test, y_pred):.4f}")

# Matriz de Confusão
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Sem Sepse", "Com Sepse"])
disp.plot(cmap='Blues')
plt.title("Matriz de Confusão - LSTM")
plt.show()
# Out:
# 1586/1586 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step
# Acurácia: 0.5112
# AUC: 0.5075
# Precisão: 0.5109
# Revocação: 0.5262
# F1-score: 0.5184

# %%
# Curva ROC
fpr, tpr, _ = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, label=f"ROC (AUC = {roc_auc:.2f})")
plt.plot([0, 1], [0, 1], 'k--', lw=1)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("Taxa de Falsos Positivos (FPR)")
plt.ylabel("Taxa de Verdadeiros Positivos (TPR)")
plt.title("Curva ROC - LSTM")
plt.legend(loc="lower right")
plt.grid(True)
plt.show()

# %%
# Curva Precision-Recall
precision, recall, _ = precision_recall_curve(y_test, y_pred_prob)
ap_score = average_precision_score(y_test, y_pred_prob)

plt.figure()
plt.plot(recall, precision, label=f"AP = {ap_score:.2f}")
plt.xlabel("Recall")
plt.ylabel("Precisão")
plt.title("Curva Precision-Recall - LSTM")
plt.legend(loc="lower left")
plt.grid(True)
plt.show()
