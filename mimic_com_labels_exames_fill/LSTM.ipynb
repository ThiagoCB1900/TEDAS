# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.metrics import accuracy_score, roc_auc_score, precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay, roc_curve, auc, precision_recall_curve, average_precision_score
import matplotlib.pyplot as plt

# %% [markdown]
# ## Carregar e tratar a base

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler  # <-- Troca aqui
import joblib
import numpy as np


# Carregar os dados
data = np.load("mimic_X_y_mask_10j.npz")
X = data['X']
y = data['y']
mask = data['mask']

# Balanceamento
idx_sepse = np.where(y == 1)[0]
idx_nsepse = np.where(y == 0)[0]
n = min(len(idx_sepse), len(idx_nsepse))
idx_balanced = np.concatenate([idx_sepse[:n], idx_nsepse[:n]])
np.random.shuffle(idx_balanced)

X_bal = X[idx_balanced]
y_bal = y[idx_balanced]
mask_bal = mask[idx_balanced]

# Divisão treino/val/teste
from sklearn.model_selection import train_test_split

X_train, X_temp, y_train, y_temp, mask_train, mask_temp = train_test_split(
    X_bal, y_bal, mask_bal, test_size=0.30, random_state=42, stratify=y_bal)

X_val, X_test, y_val, y_test, mask_val, mask_test = train_test_split(
    X_temp, y_temp, mask_temp, test_size=0.50, random_state=42, stratify=y_temp)

# Normalização segura por feature
def normalize_split_data(X_train, X_val, X_test):
    n_samples, n_janelas, n_features = X_train.shape
    X_train_norm = np.zeros_like(X_train)
    X_val_norm = np.zeros_like(X_val)
    X_test_norm = np.zeros_like(X_test)
    scalers = []

    for i in range(n_features):
        scaler = StandardScaler()  # <-- Troca aqui
        # scaler = MinMaxScaler()
        feat_train = X_train[:, :, i].reshape(-1, 1)
        scaler.fit(feat_train)  # Ajusta SOMENTE no treino

        # Aplica a mesma escala
        X_train_norm[:, :, i] = scaler.transform(feat_train).reshape(n_samples, n_janelas)
        X_val_norm[:, :, i] = scaler.transform(X_val[:, :, i].reshape(-1, 1)).reshape(X_val.shape[0], n_janelas)
        X_test_norm[:, :, i] = scaler.transform(X_test[:, :, i].reshape(-1, 1)).reshape(X_test.shape[0], n_janelas)

        scalers.append(scaler)

    return X_train_norm, X_val_norm, X_test_norm, scalers

# Executar normalização
X_train_norm, X_val_norm, X_test_norm, scalers = normalize_split_data(X_train, X_val, X_test)

# Salvar scalers
joblib.dump(scalers, "scalers_standard_lstm.pkl")  # <-- Nome atualizado

# Atualizar variáveis do pipeline
X_train, X_val, X_test = X_train_norm, X_val_norm, X_test_norm

print("✅ Normalização segura concluída com StandardScaler e scalers salvos!")
# Out:
# ✅ Normalização segura concluída com StandardScaler e scalers salvos!

# %% [markdown]
# ## Carregar sem tratar a base (V.1)

# %% [markdown]
# ### Divisão dos dados em treino, validação e teste
#
# - **Objetivo:** Separar o conjunto balanceado em três partes: treino (70%), validação (15%) e teste (15%).
# - **Como:**
#   - Primeiro, separa 70% para treino e 30% para validação+teste.
#   - Depois, divide os 30% restantes igualmente entre validação e teste.
# - **Estratificação:** A divisão mantém a proporção das classes (sepse/não sepse) em todos os conjuntos.
# - **Importância:** Garante avaliação justa do modelo e evita vazamento de dados entre treino e teste.

# %% [markdown]
# ### Construção do modelo LSTM
#
# - **Definição da entrada:** O modelo recebe sequências no formato `(janelas, variáveis)` para cada paciente.
# - **Máscara:** A camada `Masking` faz o modelo ignorar posições preenchidas com zero (usadas para padding).
# - **LSTM:** Camada principal que processa as sequências temporais, capturando padrões ao longo do tempo.
# - **Dropout:** Ajuda a evitar overfitting, desligando aleatoriamente parte dos neurônios durante o treino.
# - **Dense:** Camada totalmente conectada para refinar a representação.
# - **Saída:** Camada final com ativação sigmoide para prever a probabilidade de sepse (0 ou 1).

# %% [markdown]
# ## LSTM

# %%
# Definir a forma da entrada (janelas, variáveis)
input_shape = X_train.shape[1:]  # (10, 8)

# Construir o modelo
inputs = tf.keras.Input(shape=input_shape)
x = layers.Masking(mask_value=0.0)(inputs)
x = layers.LSTM(64, return_sequences=False)(x)
x = layers.Dropout(0.3)(x)
x = layers.Dense(32, activation='relu')(x)
outputs = layers.Dense(1, activation='sigmoid')(x)

model_lstm = models.Model(inputs, outputs)

# %% [markdown]
# ### Compilação do modelo LSTM
#
# - **O que é feito:**
#   Esta célula configura como o modelo LSTM será treinado, definindo o otimizador, a função de perda e as métricas de avaliação.
#
# - **Parâmetros definidos:**
#   - **optimizer='adam':**
#     Utiliza o otimizador Adam, que é eficiente e amplamente usado em deep learning por ajustar automaticamente a taxa de aprendizado durante o treinamento.
#   - **loss='binary_crossentropy':**
#     Define a função de perda como entropia cruzada binária, adequada para problemas de classificação binária (sepse ou não).
#   - **metrics:**
#     Lista de métricas que serão monitoradas durante o treinamento e validação:
#     - **BinaryAccuracy (accuracy):** Mede a proporção de previsões corretas (acertos) entre as amostras.
#     - **AUC (Área sob a curva ROC):** Avalia a capacidade do modelo em distinguir entre as classes, considerando diferentes limiares de decisão.
#     - **Recall (Sensibilidade):** Mede a proporção de casos positivos corretamente identificados (importante para não perder casos de sepse).
#     - **Precision (Precisão):** Mede a proporção de previsões positivas que realmente são positivas (importante para evitar alarmes falsos).
#
# - **Resumo:**
#   Com essa configuração, o modelo será treinado de forma eficiente e avaliado por métricas que ajudam a entender não só o acerto geral, mas também a capacidade de identificar corretamente casos de sepse e evitar falsos positivos.

# %%
model_lstm.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=[
        tf.keras.metrics.BinaryAccuracy(name='accuracy'),
        tf.keras.metrics.AUC(name='auc'),
        tf.keras.metrics.Recall(name='recall'),
        tf.keras.metrics.Precision(name='precision')
    ]
)

# %% [markdown]
# ### Treinamento do modelo LSTM
#
# - **O que está sendo feito:**
#   Esta célula inicia o treinamento do modelo LSTM usando os dados de treino e validação.
#
# - **Parâmetros principais:**
#   - `X_train, y_train`: Dados de entrada e rótulos para o treinamento do modelo.
#   - `validation_data=(X_val, y_val)`: Dados separados para validação, permitindo monitorar o desempenho do modelo em dados não vistos durante o treino.
#   - `epochs=50`: O modelo será treinado por até 50 ciclos completos sobre o conjunto de treino. Um número maior de épocas pode ajudar o modelo a aprender melhor, mas também pode causar overfitting se exagerado.
#   - `batch_size=64`: O modelo atualiza os pesos a cada 64 amostras. Batches maiores podem acelerar o treinamento, mas exigem mais memória.
#   - `verbose=2`: Controla o nível de detalhamento dos logs durante o treinamento (2 mostra uma linha por época).
#
# - **Por que usar validação?**
#   O conjunto de validação serve para acompanhar se o modelo está realmente aprendendo padrões úteis ou apenas decorando os dados de treino (overfitting). Assim, é possível ajustar hiperparâmetros e escolher o melhor modelo.
#
# - **Resumo:**
#   Ao final desse processo, o histórico de treinamento (`history`) terá informações sobre a evolução das métricas de desempenho em treino e validação, permitindo avaliar e comparar os resultados.

# %%
# Treinamento do modelo
history = model_lstm.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=50,
    batch_size
- val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 36/50
# 3701/3701 - 36s - 10ms/step - accuracy: 0.4998 - auc: 0.5000 - loss: 0.6932 - precision: 0.4998 - recall: 0.5018 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6931 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 37/50
# 3701/3701 - 28s - 8ms/step - accuracy: 0.4983 - auc: 0.4982 - loss: 0.6932 - precision: 0.4983 - recall: 0.4985 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6931 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 38/50
# 3701/3701 - 20s - 5ms/step - accuracy: 0.5011 - auc: 0.5010 - loss: 0.6932 - precision: 0.5011 - recall: 0.5121 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 39/50
# 3701/3701 - 29s - 8ms/step - accuracy: 0.4990 - auc: 0.4985 - loss: 0.6932 - precision: 0.4990 - recall: 0.5012 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6931 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 40/50
# 3701/3701 - 33s - 9ms/step - accuracy: 0.4996 - auc: 0.5005 - loss: 0.6932 - precision: 0.4996 - recall: 0.4211 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 41/50
# 3701/3701 - 36s - 10ms/step - accuracy: 0.5015 - auc: 0.4998 - loss: 0.6932 - precision: 0.5013 - recall: 0.5799 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 42/50
# 3701/3701 - 34s - 9ms/step - accuracy: 0.4990 - auc: 0.4992 - loss: 0.6932 - precision: 0.4992 - recall: 0.5723 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6931 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 43/50
# 3701/3701 - 29s - 8ms/step - accuracy: 0.4988 - auc: 0.4990 - loss: 0.6932 - precision: 0.4989 - recall: 0.5196 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 44/50
# 3701/3701 - 28s - 8ms/step - accuracy: 0.4994 - auc: 0.4998 - loss: 0.6932 - precision: 0.4995 - recall: 0.5561 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 45/50
# 3701/3701 - 28s - 7ms/step - accuracy: 0.4986 - auc: 0.4994 - loss: 0.6932 - precision: 0.4985 - recall: 0.4603 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 46/50
# 3701/3701 - 28s - 8ms/step - accuracy: 0.4991 - auc: 0.5003 - loss: 0.6932 - precision: 0.4991 - recall: 0.4975 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 47/50
# 3701/3701 - 28s - 7ms/step - accuracy: 0.4980 - auc: 0.4983 - loss: 0.6932 - precision: 0.4981 - recall: 0.5170 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 48/50
# 3701/3701 - 28s - 7ms/step - accuracy: 0.4992 - auc: 0.4997 - loss: 0.6932 - precision: 0.4993 - recall: 0.5602 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6931 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 49/50
# 3701/3701 - 27s - 7ms/step - accuracy: 0.5011 - auc: 0.5010 - loss: 0.6932 - precision: 0.5010 - recall: 0.5476 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6931 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 50/50
# 3701/3701 - 27s - 7ms/step - accuracy: 0.4995 - auc: 0.4995 - loss: 0.6932 - precision: 0.4996 - recall: 0.5386 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6931 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %%
input_shape = X_train.shape[1:]  # alternativo

inputs = tf.keras.Input(shape=input_shape)
x = layers.Masking(mask_value=0.0)(inputs)
x = layers.Bidirectional(layers.LSTM(64, return_sequences=True))(x)
x = layers.GlobalAveragePooling1D()(x)
x = layers.Dropout(0.2)(x)
x = layers.Dense(32, activation='relu')(x)
outputs = layers.Dense(1, activation='sigmoid')(x)

model_lstm = tf.keras.Model(inputs, outputs)
model_lstm.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=[
        tf.keras.metrics.BinaryAccuracy(name='accuracy'),
        tf.keras.metrics.AUC(name='auc'),
        tf.keras.metrics.Recall(name='recall'),
        tf.keras.metrics.Precision(name='precision')
    ]
)

# Opcional: sample_weight por quantidade de janelas válidas
sample_weights = mask_train.sum(axis=1) / mask_train.shape[1]

# Treinamento
model_lstm.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=50,
    batch_size=64,
    sample_weight=sample_weights,
    verbose=2
)
# Out:
# Epoch 1/50
# 3701/3701 - 41s - 11ms/step - accuracy: 0.5001 - auc: 0.5006 - loss: 0.6748 - precision: 0.5001 - recall: 0.9307 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6931 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 2/50
# 3701/3701 - 44s - 12ms/step - accuracy: 0.5000 - auc: 0.4994 - loss: 0.6748 - precision: 0.5000 - recall: 0.9577 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6931 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/50
# 3701/3701 - 43s - 12ms/step - accuracy: 0.5005 - auc: 0.4997 - loss: 0.6748 - precision: 0.5003 - recall: 0.8902 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6933 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 4/50
# 3701/3701 - 43s - 12ms/step - accuracy: 0.4994 - auc: 0.5000 - loss: 0.6748 - precision: 0.4997 - recall: 0.9667 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 5/50
# 3701/3701 - 48s - 13ms/step - accuracy: 0.5016 - auc: 0.5011 - loss: 0.6748 - precision: 0.5009 - recall: 0.8562 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 6/50
# 3701/3701 - 49s - 13ms/step - accuracy: 0.5007 - auc: 0.5018 - loss: 0.6748 - precision: 0.5004 - recall: 0.8686 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6931 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 7/50
# 3701/3701 - 47s - 13ms/step - accuracy: 0.4996 - auc: 0.4981 - loss: 0.6748 - precision: 0.4998 - recall: 0.9636 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 8/50
# 3701/3701 - 51s - 14ms/step - accuracy: 0.4999 - auc: 0.4986 - loss: 0.6748 - precision: 0.5000 - recall: 0.9867 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 9/50
# 3701/3701 - 49s - 13ms/step - accuracy: 0.4996 - auc: 0.4977 - loss: 0.6748 - precision: 0.4998 - recall: 0.9902 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 10/50
# 3701/3701 - 48s - 13ms/step - accuracy: 0.5004 - auc: 0.5012 - loss: 0.6748 - precision: 0.5002 - recall: 0.9431 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 11/50
# 3701/3701 - 51s - 14ms/step - accuracy: 0.4998 - auc: 0.5003 - loss: 0.6748 - precision: 0.4999 - recall: 0.9573 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 12/50
# 3701/3701 - 50s - 13ms/step - accuracy: 0.5008 - auc: 0.5015 - loss: 0.6748 - precision: 0.5005 - recall: 0.8568 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 13/50
# 3701/3701 - 28s - 8ms/step - accuracy: 0.5001 - auc: 0.4990 - loss: 0.6748 - precision: 0.5000 - recall: 0.9114 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6933 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 14/50
# 3701/3701 - 27s - 7ms/step - accuracy: 0.4998 - auc: 0.4998 - loss: 0.6748 - precision: 0.4999 - recall: 0.9941 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6931 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 15/50
# 3701/3701 - 26s - 7ms/step - accuracy: 0.5003 - auc: 0.4991 - loss: 0.6748 - precision: 0.5001 - recall: 0.9530 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 16/50
# 3701/3701 - 29s - 8ms/step - accuracy: 0.4998 - auc: 0.4997 - loss: 0.6748 - precision: 0.4999 - recall: 0.9406 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6933 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 17/50
# 3701/3701 - 29s - 8ms/step - accuracy: 0.4998 - auc: 0.4981 - loss: 0.6748 - precision: 0.4999 - recall: 0.9958 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 18/50
# 3701/3701 - 29s - 8ms/step - accuracy: 0.5001 - auc: 0.4992 - loss: 0.6748 - precision: 0.5001 - recall: 0.9247 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6933 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 19/50
# 3701/3701 - 29s - 8ms/step - accuracy: 0.4997 - auc: 0.5020 - loss: 0.6748 - precision: 0.4998 - recall: 0.9170 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6934 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 20/50
# 3701/3701 - 29s - 8ms/step - accuracy: 0.4995 - auc: 0.4996 - loss: 0.6748 - precision: 0.4998 - recall: 0.9620 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 21/50
# 3701/3701 - 41s - 11ms/step - accuracy: 0.5005 - auc: 0.5004 - loss: 0.6748 - precision: 0.5003 - recall: 0.9081 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 22/50
# 3701/3701 - 29s - 8ms/step - accuracy: 0.4998 - auc: 0.5012 - loss: 0.6748 - precision: 0.4999 - recall: 0.9384 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 23/50
# 3701/3701 - 29s - 8ms/step - accuracy: 0.4996 - auc: 0.4992 - loss: 0.6748 - precision: 0.4998 - recall: 0.9742 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 24/50
# 3701/3701 - 30s - 8ms/step - accuracy: 0.5005 - auc: 0.5016 - loss: 0.6748 - precision: 0.5003 - recall: 0.8556 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6933 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 25/50
# 3701/3701 - 30s - 8ms/step - accuracy: 0.4993 - auc: 0.4997 - loss: 0.6748 - precision: 0.4996 - recall: 0.9371 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 26/50
# 3701/3701 - 29s - 8ms/step - accuracy: 0.5001 - auc: 0.5001 - loss: 0.6748 - precision: 0.5001 - recall: 0.9004 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 27/50
# 3701/3701 - 29s - 8ms/step - accuracy: 0.5011 - auc: 0.5004 - loss: 0.6748 - precision: 0.5006 - recall: 0.8843 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 28/50
# 3701/3701 - 29s - 8ms/step - accuracy: 0.5003 - auc: 0.5002 - loss: 0.6748 - precision: 0.5002 - recall: 0.9195 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 29/50
# 3701/3701 - 29s - 8ms/step - accuracy: 0.4997 - auc: 0.4987 - loss: 0.6748 - precision: 0.4999 - recall: 0.9927 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6931 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 30/50
# 3701/3701 - 29s - 8ms/step - accuracy: 0.4994 - auc: 0.4994 - loss: 0.6748 - precision: 0.4997 - recall: 0.9432 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 31/50
# 3701/3701 - 29s - 8ms/step - accuracy: 0.4996 - auc: 0.5006 - loss: 0.6748 - precision: 0.4998 - recall: 0.9755 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6931 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 32/50
# 3701/3701 - 29s - 8ms/step - accuracy: 0.4995 - auc: 0.4985 - loss: 0.6748 - precision: 0.4997 - recall: 0.9428 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 33/50
# 3701/3701 - 30s - 8ms/step - accuracy: 0.4995 - auc: 0.5008 - loss: 0.6748 - precision: 0.4997 - recall: 0.9118 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6931 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 34/50
# 3701/3701 - 30s - 8ms/step - accuracy: 0.4994 - auc: 0.4998 - loss: 0.6748 - precision: 0.4997 - recall: 0.9327 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6933 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 35/50
# 3701/3701 - 29s - 8ms/step - accuracy: 0.4996 - auc: 0.5008 - loss: 0.6748 - precision: 0.4998 - recall: 0.9472 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 36/50
# 3701/3701 - 30s - 8ms/step - accuracy: 0.4997 - auc: 0.5003 - loss: 0.6748 - precision: 0.4998 - recall: 0.9335 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 37/50
# 3701/3701 - 29s - 8ms/step - accuracy: 0.5000 - auc: 0.4995 - loss: 0.6748 - precision: 0.5000 - recall: 0.9381 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 38/50
# 3701/3701 - 29s - 8ms/step - accuracy: 0.4998 - auc: 0.4981 - loss: 0.6748 - precision: 0.4999 - recall: 0.9557 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 39/50
# 3701/3701 - 29s - 8ms/step - accuracy: 0.4998 - auc: 0.4995 - loss: 0.6748 - precision: 0.4999 - recall: 0.9641 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6933 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 40/50
# 3701/3701 - 29s - 8ms/step - accuracy: 0.4998 - auc: 0.4997 - loss: 0.6748 - precision: 0.4999 - recall: 0.9298 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 41/50
# 3701/3701 - 30s - 8ms/step - accuracy: 0.4993 - auc: 0.4992 - loss: 0.6748 - precision: 0.4996 - recall: 0.9634 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 42/50
# 3701/3701 - 30s - 8ms/step - accuracy: 0.5001 - auc: 0.4995 - loss: 0.6748 - precision: 0.5001 - recall: 0.9255 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 43/50
# 3701/3701 - 30s - 8ms/step - accuracy: 0.5001 - auc: 0.5004 - loss: 0.6748 - precision: 0.5000 - recall: 0.8790 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 44/50
# 3701/3701 - 29s - 8ms/step - accuracy: 0.4994 - auc: 0.4990 - loss: 0.6748 - precision: 0.4997 - recall: 0.9632 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 45/50
# 3701/3701 - 29s - 8ms/step - accuracy: 0.4996 - auc: 0.4979 - loss: 0.6748 - precision: 0.4998 - recall: 0.9745 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6934 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 46/50
# 3701/3701 - 29s - 8ms/step - accuracy: 0.5005 - auc: 0.4997 - loss: 0.6748 - precision: 0.5003 - recall: 0.9181 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6934 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 47/50
# 3701/3701 - 29s - 8ms/step - accuracy: 0.4997 - auc: 0.4990 - loss: 0.6748 - precision: 0.4998 - recall: 0.9681 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6933 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 48/50
# 3701/3701 - 30s - 8ms/step - accuracy: 0.5000 - auc: 0.4977 - loss: 0.6748 - precision: 0.5000 - recall: 1.0000 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 49/50
# 3701/3701 - 29s - 8ms/step - accuracy: 0.4998 - auc: 0.4988 - loss: 0.6748 - precision: 0.4999 - recall: 0.9414 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 50/50
# 3701/3701 - 29s - 8ms/step - accuracy: 0.4994 - auc: 0.4990 - loss: 0.6748 - precision: 0.4997 - recall: 0.9808 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.5000 - val_recall: 1.0000

# %% [markdown]
# ### Predição e ajuste de limiar
#
# - **Predição:**
#   O modelo LSTM gera, para cada amostra de teste, uma probabilidade (`y_pred_prob`) de ser positivo (ter sepse). Essas probabilidades são valores contínuos entre 0 e 1.
#
# - **Ajuste de limiar:**
#   Para transformar as probabilidades em classes (0 ou 1), define-se um limiar (threshold), normalmente 0.5.
#   - Se a probabilidade for maior ou igual ao limiar, a previsão é positiva (1).
#   - Se for menor, a previsão é negativa (0).
#
# - **Importância:**
#   O ajuste do limiar pode ser alterado conforme a necessidade do problema, por exemplo, para aumentar o recall ou a precisão, dependendo do objetivo clinico

# %%
# Definir a forma da entrada (janelas, variáveis)
input_shape = X_train.shape[1:]  # (10, 8)

# Construir o modelo aprimorado
inputs = tf.keras.Input(shape=input_shape)

# A camada Masking é ótima para dados faltantes ou preenchidos com zero
x = layers.Masking(mask_value=0.0)(inputs)

# Camada Bidirecional para capturar contexto de ambas as direções
# return_sequences=True é necessário para empilhar com outra camada recorrente
x = layers.Bidirectional(layers.LSTM(64, return_sequences=True))(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.4)(x) # Aumentar um pouco o dropout para um modelo mais complexo

# Segunda camada LSTM para aprender padrões mais profundos
x = layers.Bidirectional(layers.LSTM(32, return_sequences=False))(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.4)(x)

# Camada densa para classificação final
x = layers.Dense(32)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)
x = layers.Dropout(0.5)(x) # Dropout final antes da camada de saída

outputs = layers.Dense(1, activation='sigmoid')(x)

model_lstm = models.Model(inputs, outputs)

# %% [markdown]
# ## Resultados

# %%
# Predição
y_pred_prob = model_lstm.predict(X_test).flatten()

# Ajustar limiar (exemplo: 0.5)
limiar = 0.5
y_pred = (y_pred_prob >= limiar).astype(int)

# Métricas
print(f"Acurácia: {accuracy_score(y_test, y_pred):.4f}")
print(f"AUC: {roc_auc_score(y_test, y_pred_prob):.4f}")
print(f"Precisão: {precision_score(y_test, y_pred):.4f}")
print(f"Revocação: {recall_score(y_test, y_pred):.4f}")
print(f"F1-score: {f1_score(y_test, y_pred):.4f}")

# Matriz de Confusão
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Sem Sepse", "Com Sepse"])
disp.plot(cmap='Blues')
plt.title("Matriz de Confusão - LSTM")
plt.show()
# Out:
# 1586/1586 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step
# Acurácia: 0.5000
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 10
#       8 # Métricas
#       9 print(f"Acurácia: {accuracy_score(y_test, y_pred):.4f}")
# ---> 10 print(f"AUC: {roc_auc_score(y_test, y_pred_prob):.4f}")
#      11 print(f"Precisão: {precision_score(y_test, y_pred):.4f}")
#      12 print(f"Revocação: {recall_score(y_test, y_pred):.4f}")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_ranking.py:665, in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr, multi_class, labels)
#     663 y_type = type_of_target(y_true, input_name="y_true")
#     664 y_true = check_array(y_true, ensure_2d=False, dtype=None)
# --> 665 y_score = check_array(y_score, ensure_2d=False)
#     667 if y_type == "multiclass" or (
#     668     y_type == "binary" and y_score.ndim == 2 and y_score.shape[1] > 2
#     669 ):
#     670     # do not support partial ROC computation for multiclass
#     671     if max_fpr is not None and max_fpr != 1.0:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1105, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1099     raise ValueError(
#    1100         f"Found array with dim {array.ndim},"
#    1101         f" while dim <= 2 is required{context}."
#    1102     )
#    1104 if ensure_all_finite:
# -> 1105     _assert_all_finite(
#    1106         array,
#    1107         input_name=input_name,
#    1108         estimator_name=estimator_name,
#    1109         allow_nan=ensure_all_finite == "allow-nan",
#    1110     )
#    1112 if copy:
#    1113     if _is_numpy_namespace(xp):
#    1114         # only make a copy if `array` and `array_orig` may share memory`
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:120, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     117 if first_pass_isfinite:
#     118     return
# --> 120 _assert_all_finite_element_wise(
#     121     X,
#     122     xp=xp,
#     123     allow_nan=allow_nan,
#     124     msg_dtype=msg_dtype,
#     125     estimator_name=estimator_name,
#     126     input_name=input_name,
#     127 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:169, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     152 if estimator_name and input_name == "X" and has_nan_error:
#     153     # Improve the error message on how to handle missing values in
#     154     # scikit-learn.
#     155     msg_err += (
#     156         f"\n{estimator_name} does not accept missing values"
#     157         " encoded as NaN natively. For supervised learning, you might want"
#    (...)    167         "#estimators-that-handle-nan-values"
#     168     )
# --> 169 raise ValueError(msg_err)
#
# ValueError: Input contains NaN.

# %%
# Curva ROC
fpr, tpr, _ = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, label=f"ROC (AUC = {roc_auc:.2f})")
plt.plot([0, 1], [0, 1], 'k--', lw=1)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("Taxa de Falsos Positivos (FPR)")
plt.ylabel("Taxa de Verdadeiros Positivos (TPR)")
plt.title("Curva ROC - LSTM")
plt.legend(loc="lower right")
plt.grid(True)
plt.show()

# %%
# Curva Precision-Recall
precision, recall, _ = precision_recall_curve(y_test, y_pred_prob)
ap_score = average_precision_score(y_test, y_pred_prob)

plt.figure()
plt.plot(recall, precision, label=f"AP = {ap_score:.2f}")
plt.xlabel("Recall")
plt.ylabel("Precisão")
plt.title("Curva Precision-Recall - LSTM")
plt.legend(loc="lower left")
plt.grid(True)
plt.show()
