# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.metrics import accuracy_score, roc_auc_score, precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay, roc_curve, auc, precision_recall_curve, average_precision_score
import matplotlib.pyplot as plt

# %% [markdown]
# ## Carregar e tratar a base

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler  # <-- Troca aqui
import joblib
import numpy as np


# Carregar os dados
data = np.load("mimic_X_y_mask_10j.npz")
X = data['X']
y = data['y']
mask = data['mask']

# Balanceamento
idx_sepse = np.where(y == 1)[0]
idx_nsepse = np.where(y == 0)[0]
n = min(len(idx_sepse), len(idx_nsepse))
idx_balanced = np.concatenate([idx_sepse[:n], idx_nsepse[:n]])
np.random.shuffle(idx_balanced)

X_bal = X[idx_balanced]
y_bal = y[idx_balanced]
mask_bal = mask[idx_balanced]

# Divisão treino/val/teste
from sklearn.model_selection import train_test_split

X_train, X_temp, y_train, y_temp, mask_train, mask_temp = train_test_split(
    X_bal, y_bal, mask_bal, test_size=0.30, random_state=42, stratify=y_bal)

X_val, X_test, y_val, y_test, mask_val, mask_test = train_test_split(
    X_temp, y_temp, mask_temp, test_size=0.50, random_state=42, stratify=y_temp)

# Normalização segura por feature
def normalize_split_data(X_train, X_val, X_test):
    n_samples, n_janelas, n_features = X_train.shape
    X_train_norm = np.zeros_like(X_train)
    X_val_norm = np.zeros_like(X_val)
    X_test_norm = np.zeros_like(X_test)
    scalers = []

    for i in range(n_features):
        scaler = StandardScaler()  # <-- Troca aqui
        # scaler = MinMaxScaler()
        feat_train = X_train[:, :, i].reshape(-1, 1)
        scaler.fit(feat_train)  # Ajusta SOMENTE no treino

        # Aplica a mesma escala
        X_train_norm[:, :, i] = scaler.transform(feat_train).reshape(n_samples, n_janelas)
        X_val_norm[:, :, i] = scaler.transform(X_val[:, :, i].reshape(-1, 1)).reshape(X_val.shape[0], n_janelas)
        X_test_norm[:, :, i] = scaler.transform(X_test[:, :, i].reshape(-1, 1)).reshape(X_test.shape[0], n_janelas)

        scalers.append(scaler)

    return X_train_norm, X_val_norm, X_test_norm, scalers

# Executar normalização
X_train_norm, X_val_norm, X_test_norm, scalers = normalize_split_data(X_train, X_val, X_test)

# Salvar scalers
joblib.dump(scalers, "scalers_standard_lstm.pkl")  # <-- Nome atualizado

# Atualizar variáveis do pipeline
X_train, X_val, X_test = X_train_norm, X_val_norm, X_test_norm

print("✅ Normalização segura concluída com StandardScaler e scalers salvos!")
# Out:
# ✅ Normalização segura concluída com StandardScaler e scalers salvos!

# %% [markdown]
# ## Carregar sem tratar a base (V.1)

# %% [markdown]
# ### Divisão dos dados em treino, validação e teste
#
# - **Objetivo:** Separar o conjunto balanceado em três partes: treino (70%), validação (15%) e teste (15%).
# - **Como:**
#   - Primeiro, separa 70% para treino e 30% para validação+teste.
#   - Depois, divide os 30% restantes igualmente entre validação e teste.
# - **Estratificação:** A divisão mantém a proporção das classes (sepse/não sepse) em todos os conjuntos.
# - **Importância:** Garante avaliação justa do modelo e evita vazamento de dados entre treino e teste.

# %% [markdown]
# ### Construção do modelo LSTM
#
# - **Definição da entrada:** O modelo recebe sequências no formato `(janelas, variáveis)` para cada paciente.
# - **Máscara:** A camada `Masking` faz o modelo ignorar posições preenchidas com zero (usadas para padding).
# - **LSTM:** Camada principal que processa as sequências temporais, capturando padrões ao longo do tempo.
# - **Dropout:** Ajuda a evitar overfitting, desligando aleatoriamente parte dos neurônios durante o treino.
# - **Dense:** Camada totalmente conectada para refinar a representação.
# - **Saída:** Camada final com ativação sigmoide para prever a probabilidade de sepse (0 ou 1).

# %% [markdown]
# ## LSTM

# %%
# Definir a forma da entrada (janelas, variáveis)
input_shape = X_train.shape[1:]  # (10, 8)

# Construir o modelo
inputs = tf.keras.Input(shape=input_shape)
x = layers.Masking(mask_value=0.0)(inputs)
x = layers.LSTM(64, return_sequences=False)(x)
x = layers.Dropout(0.3)(x)
x = layers.Dense(32, activation='relu')(x)
outputs = layers.Dense(1, activation='sigmoid')(x)

model_lstm = models.Model(inputs, outputs)

# %% [markdown]
# ### Compilação do modelo LSTM
#
# - **O que é feito:**
#   Esta célula configura como o modelo LSTM será treinado, definindo o otimizador, a função de perda e as métricas de avaliação.
#
# - **Parâmetros definidos:**
#   - **optimizer='adam':**
#     Utiliza o otimizador Adam, que é eficiente e amplamente usado em deep learning por ajustar automaticamente a taxa de aprendizado durante o treinamento.
#   - **loss='binary_crossentropy':**
#     Define a função de perda como entropia cruzada binária, adequada para problemas de classificação binária (sepse ou não).
#   - **metrics:**
#     Lista de métricas que serão monitoradas durante o treinamento e validação:
#     - **BinaryAccuracy (accuracy):** Mede a proporção de previsões corretas (acertos) entre as amostras.
#     - **AUC (Área sob a curva ROC):** Avalia a capacidade do modelo em distinguir entre as classes, considerando diferentes limiares de decisão.
#     - **Recall (Sensibilidade):** Mede a proporção de casos positivos corretamente identificados (importante para não perder casos de sepse).
#     - **Precision (Precisão):** Mede a proporção de previsões positivas que realmente são positivas (importante para evitar alarmes falsos).
#
# - **Resumo:**
#   Com essa configuração, o modelo será treinado de forma eficiente e avaliado por métricas que ajudam a entender não só o acerto geral, mas também a capacidade de identificar corretamente casos de sepse e evitar falsos positivos.

# %%
model_lstm.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=[
        tf.keras.metrics.BinaryAccuracy(name='accuracy'),
        tf.keras.metrics.AUC(name='auc'),
        tf.keras.metrics.Recall(name='recall'),
        tf.keras.metrics.Precision(name='precision')
    ]
)

# %% [markdown]
# ### Treinamento do modelo LSTM
#
# - **O que está sendo feito:**
#   Esta célula inicia o treinamento do modelo LSTM usando os dados de treino e validação.
#
# - **Parâmetros principais:**
#   - `X_train, y_train`: Dados de entrada e rótulos para o treinamento do modelo.
#   - `validation_data=(X_val, y_val)`: Dados separados para validação, permitindo monitorar o desempenho do modelo em dados não vistos durante o treino.
#   - `epochs=50`: O modelo será treinado por até 50 ciclos completos sobre o conjunto de treino. Um número maior de épocas pode ajudar o modelo a aprender melhor, mas também pode causar overfitting se exagerado.
#   - `batch_size=64`: O modelo atualiza os pesos a cada 64 amostras. Batches maiores podem acelerar o treinamento, mas exigem mais memória.
#   - `verbose=2`: Controla o nível de detalhamento dos logs durante o treinamento (2 mostra uma linha por época).
#
# - **Por que usar validação?**
#   O conjunto de validação serve para acompanhar se o modelo está realmente aprendendo padrões úteis ou apenas decorando os dados de treino (overfitting). Assim, é possível ajustar hiperparâmetros e escolher o melhor modelo.
#
# - **Resumo:**
#   Ao final desse processo, o histórico de treinamento (`history`) terá informações sobre a evolução das métricas de desempenho em treino e validação, permitindo avaliar e comparar os resultados.

# %%
# Treinamento do modelo
history = model_lstm.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=50,
    batch_size=64,
    verbose=2
)
# Out:
# Epoch 1/50
# 347/347 - 3s - 8ms/step - accuracy: 0.6878 - auc: 0.7485 - loss: 0.5947 - precision: 0.6933 - recall: 0.6736 - val_accuracy: 0.6751 - val_auc: 0.7439 - val_loss: 0.5989 - val_precision: 0.6772 - val_recall: 0.6692
# Epoch 2/50
# 347/347 - 1s - 4ms/step - accuracy: 0.7052 - auc: 0.7670 - loss: 0.5784 - precision: 0.7081 - recall: 0.6984 - val_accuracy: 0.6839 - val_auc: 0.7480 - val_loss: 0.5957 - val_precision: 0.6827 - val_recall: 0.6873
# Epoch 3/50
# 347/347 - 1s - 4ms/step - accuracy: 0.7107 - auc: 0.7702 - loss: 0.5754 - precision: 0.7129 - recall: 0.7058 - val_accuracy: 0.6867 - val_auc: 0.7511 - val_loss: 0.5945 - val_precision: 0.7040 - val_recall: 0.6443
# Epoch 4/50
# 347/347 - 1s - 4ms/step - accuracy: 0.7109 - auc: 0.7716 - loss: 0.5738 - precision: 0.7116 - recall: 0.7092 - val_accuracy: 0.6865 - val_auc: 0.7523 - val_loss: 0.5980 - val_precision: 0.7088 - val_recall: 0.6330
# Epoch 5/50
# 347/347 - 1s - 4ms/step - accuracy: 0.7118 - auc: 0.7737 - loss: 0.5716 - precision: 0.7154 - recall: 0.7033 - val_accuracy: 0.6917 - val_auc: 0.7538 - val_loss: 0.5919 - val_precision: 0.6935 - val_recall: 0.6873
# Epoch 6/50
# 347/347 - 1s - 4ms/step - accuracy: 0.7114 - auc: 0.7766 - loss: 0.5687 - precision: 0.7102 - recall: 0.7141 - val_accuracy: 0.6903 - val_auc: 0.7551 - val_loss: 0.5882 - val_precision: 0.6890 - val_recall: 0.6936
# Epoch 7/50
# 347/347 - 1s - 4ms/step - accuracy: 0.7146 - auc: 0.7787 - loss: 0.5665 - precision: 0.7145 - recall: 0.7149 - val_accuracy: 0.6960 - val_auc: 0.7596 - val_loss: 0.5934 - val_precision: 0.7041 - val_recall: 0.6759
# Epoch 8/50
# 347/347 - 1s - 3ms/step - accuracy: 0.7130 - auc: 0.7787 - loss: 0.5664 - precision: 0.7119 - recall: 0.7153 - val_accuracy: 0.6983 - val_auc: 0.7603 - val_loss: 0.5833 - val_precision: 0.6929 - val_recall: 0.7122
# Epoch 9/50
# 347/347 - 1s - 4ms/step - accuracy: 0.7136 - auc: 0.7791 - loss: 0.5663 - precision: 0.7118 - recall: 0.7181 - val_accuracy: 0.6957 - val_auc: 0.7585 - val_loss: 0.5849 - val_precision: 0.6939 - val_recall: 0.7004
# Epoch 10/50
# 347/347 - 1s - 4ms/step - accuracy: 0.7136 - auc: 0.7814 - loss: 0.5636 - precision: 0.7125 - recall: 0.7162 - val_accuracy: 0.6970 - val_auc: 0.7582 - val_loss: 0.5908 - val_precision: 0.6960 - val_recall: 0.6995
# Epoch 11/50
# 347/347 - 1s - 4ms/step - accuracy: 0.7158 - auc: 0.7829 - loss: 0.5622 - precision: 0.7145 - recall: 0.7190 - val_accuracy: 0.6979 - val_auc: 0.7625 - val_loss: 0.5819 - val_precision: 0.7051 - val_recall: 0.6802
# Epoch 12/50
# 347/347 - 1s - 3ms/step - accuracy: 0.7153 - auc: 0.7836 - loss: 0.5613 - precision: 0.7156 - recall: 0.7146 - val_accuracy: 0.6934 - val_auc: 0.7620 - val_loss: 0.5830 - val_precision: 0.7055 - val_recall: 0.6641
# Epoch 13/50
# 347/347 - 1s - 4ms/step - accuracy: 0.7192 - auc: 0.7858 - loss: 0.5587 - precision: 0.7193 - recall: 0.7189 - val_accuracy: 0.6922 - val_auc: 0.7544 - val_loss: 0.5895 - val_precision: 0.6777 - val_recall: 0.7328
# Epoch 14/50
# 347/347 - 1s - 4ms/step - accuracy: 0.7198 - auc: 0.7856 - loss: 0.5593 - precision: 0.7177 - recall: 0.7246 - val_accuracy: 0.6941 - val_auc: 0.7652 - val_loss: 0.5788 - val_precision: 0.6858 - val_recall: 0.7164
# Epoch 15/50
# 347/347 - 1s - 4ms/step - accuracy: 0.7193 - auc: 0.7863 - loss: 0.5582 - precision: 0.7191 - recall: 0.7196 - val_accuracy: 0.6955 - val_auc: 0.7651 - val_loss: 0.5799 - val_precision: 0.7039 - val_recall: 0.6751
# Epoch 16/50
# 347/347 - 1s - 4ms/step - accuracy: 0.7187 - auc: 0.7887 - loss: 0.5557 - precision: 0.7193 - recall: 0.7172 - val_accuracy: 0.6909 - val_auc: 0.7654 - val_loss: 0.5824 - val_precision: 0.6720 - val_recall: 0.7459
# Epoch 17/50
# 347/347 - 1s - 4ms/step - accuracy: 0.7221 - auc: 0.7893 - loss: 0.5557 - precision: 0.7190 - recall: 0.7292 - val_accuracy: 0.7054 - val_auc: 0.7697 - val_loss: 0.5738 - val_precision: 0.7035 - val_recall: 0.7101
# Epoch 18/50
# 347/347 - 1s - 4ms/step - accuracy: 0.7215 - auc: 0.7895 - loss: 0.5548 - precision: 0.7205 - recall: 0.7239 - val_accuracy: 0.7023 - val_auc: 0.7706 - val_loss: 0.5750 - val_precision: 0.6987 - val_recall: 0.7113
# Epoch 19/50
# 347/347 - 1s - 4ms/step - accuracy: 0.7221 - auc: 0.7918 - loss: 0.5528 - precision: 0.7209 - recall: 0.7248 - val_accuracy: 0.7019 - val_auc: 0.7717 - val_loss: 0.5776 - val_precision: 0.7171 - val_recall: 0.6667
# Epoch 20/50
# 347/347 - 1s - 4ms/step - accuracy: 0.7265 - auc: 0.7929 - loss: 0.5515 - precision: 0.7266 - recall: 0.7262 - val_accuracy: 0.7061 - val_auc: 0.7747 - val_loss: 0.5702 - val_precision: 0.7106 - val_recall: 0.6953
# Epoch 21/50
# 347/347 - 1s - 3ms/step - accuracy: 0.7231 - auc: 0.7942 - loss: 0.5498 - precision: 0.7219 - recall: 0.7259 - val_accuracy: 0.6953 - val_auc: 0.7679 - val_loss: 0.5780 - val_precision: 0.7016 - val_recall: 0.6797
# Epoch 22/50
# 347/347 - 1s - 4ms/step - accuracy: 0.7235 - auc: 0.7938 - loss: 0.5508 - precision: 0.7245 - recall: 0.7214 - val_accuracy: 0.7056 - val_auc: 0.7725 - val_loss: 0.5716 - val_precision: 0.6940 - val_recall: 0.7358
# Epoch 23/50
# 347/347 - 1s - 4ms/step - accuracy: 0.7232 - auc: 0.7949 - loss: 0.5491 - precision: 0.7222 - recall: 0.7253 - val_accuracy: 0.6987 - val_auc: 0.7729 - val_loss: 0.5727 - val_precision: 0.6799 - val_recall: 0.7509
# Epoch 24/50
# 347/347 - 1s - 4ms/step - accuracy: 0.7233 - auc: 0.7964 - loss: 0.5475 - precision: 0.7226 - recall: 0.7250 - val_accuracy: 0.7054 - val_auc: 0.7751 - val_loss: 0.5692 - val_precision: 0.7056 - val_recall: 0.7050
# Epoch 25/50
# 347/347 - 1s - 3ms/step - accuracy: 0.7275 - auc: 0.7967 - loss: 0.5474 - precision: 0.7279 - recall: 0.7266 - val_accuracy: 0.7027 - val_auc: 0.7774 - val_loss: 0.5673 - val_precision: 0.7113 - val_recall: 0.6823
# Epoch 26/50
# 347/347 - 1s - 4ms/step - accuracy: 0.7281 - auc: 0.7986 - loss: 0.5453 - precision: 0.7298 - recall: 0.7246 - val_accuracy: 0.7010 - val_auc: 0.7745 - val_loss: 0.5705 - val_precision: 0.7008 - val_recall: 0.7016
# Epoch 27/50
# 347/347 - 1s - 3ms/step - accuracy: 0.7254 - auc: 0.7983 - loss: 0.5454 - precision: 0.7280 - recall: 0.7197 - val_accuracy: 0.7056 - val_auc: 0.7767 - val_loss: 0.5670 - val_precision: 0.6987 - val_recall: 0.7231
# Epoch 28/50
# 347/347 - 1s - 4ms/step - accuracy: 0.7260 - auc: 0.7991 - loss: 0.5445 - precision: 0.7272 - recall: 0.7232 - val_accuracy: 0.7019 - val_auc: 0.7736 - val_loss: 0.5732 - val_precision: 0.7083 - val_recall: 0.6865
# Epoch 29/50
# 347/347 - 1s - 4ms/step - accuracy: 0.7266 - auc: 0.7988 - loss: 0.5448 - precision: 0.7277 - recall: 0.7244 - val_accuracy: 0.7044 - val_auc: 0.7777 - val_loss: 0.5666 - val_precision: 0.6989 - val_recall: 0.7181
# Epoch 30/50
# 347/347 - 1s - 4ms/step - accuracy: 0.7306 - auc: 0.7997 - loss: 0.5438 - precision: 0.7325 - recall: 0.7265 - val_accuracy: 0.7033 - val_auc: 0.7759 - val_loss: 0.5683 - val_precision: 0.6937 - val_recall: 0.7282
# Epoch 31/50
# 347/347 - 1s - 4ms/step - accuracy: 0.7302 - auc: 0.8013 - loss: 0.5419 - precision: 0.7337 - recall: 0.7227 - val_accuracy: 0.7048 - val_auc: 0.7764 - val_loss: 0.5700 - val_precision: 0.7020 - val_recall: 0.7118
# Epoch 32/50
# 347/347 - 1s - 4ms/step - accuracy: 0.7269 - auc: 0.8008 - loss: 0.5423 - precision: 0.7307 - recall: 0.7186 - val_accuracy: 0.7046 - val_auc: 0.7790 - val_loss: 0.5666 - val_precision: 0.6978 - val_recall: 0.7219
# Epoch 33/50
# 347/347 - 1s - 4ms/step - accuracy: 0.7307 - auc: 0.8021 - loss: 0.5411 - precision: 0.7312 - recall: 0.7296 - val_accuracy: 0.7025 - val_auc: 0.7746 - val_loss: 0.5699 - val_precision: 0.7005 - val_recall: 0.7075
# Epoch 34/50
# 347/347 - 1s - 4ms/step - accuracy: 0.7298 - auc: 0.8035 - loss: 0.5392 - precision: 0.7311 - recall: 0.7270 - val_accuracy: 0.7056 - val_auc: 0.7802 - val_loss: 0.5654 - val_precision: 0.7105 - val_recall: 0.6941
# Epoch 35/50
# 347/347 - 1s - 4ms/step - accuracy: 0.7297 - auc: 0.8020 - loss: 0.5412 - precision: 0.7298 - recall: 0.7297 - val_accuracy: 0.7033 - val_auc: 0.7791 - val_loss: 0.5682 - val_precision: 0.7058 - val_recall: 0.6974
# Epoch 36/50
# 347/347 - 1s - 4ms/step - accuracy: 0.7314 - auc: 0.8047 - loss: 0.5380 - precision: 0.7349 - recall: 0.7241 - val_accuracy: 0.7038 - val_auc: 0.7759 - val_loss: 0.5723 - val_precision: 0.7004 - val_recall: 0.7122
# Epoch 37/50
# 347/347 - 1s - 4ms/step - accuracy: 0.7326 - auc: 0.8043 - loss: 0.5383 - precision: 0.7358 - recall: 0.7260 - val_accuracy: 0.7021 - val_auc: 0.7802 - val_loss: 0.5692 - val_precision: 0.7033 - val_recall: 0.6991
# Epoch 38/50
# 347/347 - 1s - 4ms/step - accuracy: 0.7302 - auc: 0.8058 - loss: 0.5363 - precision: 0.7325 - recall: 0.7254 - val_accuracy: 0.6985 - val_auc: 0.7779 - val_loss: 0.5669 - val_precision: 0.7034 - val_recall: 0.6865
# Epoch 39/50
# 347/347 - 1s - 4ms/step - accuracy: 0.7323 - auc: 0.8072 - loss: 0.5351 - precision: 0.7345 - recall: 0.7276 - val_accuracy: 0.7008 - val_auc: 0.7790 - val_loss: 0.5737 - val_precision: 0.6899 - val_recall: 0.7295
# Epoch 40/50
# 347/347 - 1s - 4ms/step - accuracy: 0.7344 - auc: 0.8077 - loss: 0.5346 - precision: 0.7385 - recall: 0.7260 - val_accuracy: 0.7010 - val_auc: 0.7768 - val_loss: 0.5683 - val_precision: 0.7147 - val_recall: 0.6692
# Epoch 41/50
# 347/347 - 1s - 4ms/step - accuracy: 0.7363 - auc: 0.8081 - loss: 0.5342 - precision: 0.7392 - recall: 0.7301 - val_accuracy: 0.7038 - val_auc: 0.7764 - val_loss: 0.5690 - val_precision: 0.7058 - val_recall: 0.6987
# Epoch 42/50
# 347/347 - 1s - 4ms/step - accuracy: 0.7359 - auc: 0.8094 - loss: 0.5328 - precision: 0.7365 - recall: 0.7346 - val_accuracy: 0.7073 - val_auc: 0.7797 - val_loss: 0.5659 - val_precision: 0.7072 - val_recall: 0.7075
# Epoch 43/50
# 347/347 - 1s - 3ms/step - accuracy: 0.7347 - auc: 0.8094 - loss: 0.5327 - precision: 0.7372 - recall: 0.7293 - val_accuracy: 0.7014 - val_auc: 0.7779 - val_loss: 0.5660 - val_precision: 0.6990 - val_recall: 0.7075
# Epoch 44/50
# 347/347 - 1s - 3ms/step - accuracy: 0.7344 - auc: 0.8112 - loss: 0.5305 - precision: 0.7360 - recall: 0.7310 - val_accuracy: 0.7021 - val_auc: 0.7744 - val_loss: 0.5781 - val_precision: 0.6944 - val_recall: 0.7219
# Epoch 45/50
# 347/347 - 1s - 4ms/step - accuracy: 0.7345 - auc: 0.8092 - loss: 0.5330 - precision: 0.7390 - recall: 0.7253 - val_accuracy: 0.7050 - val_auc: 0.7784 - val_loss: 0.5664 - val_precision: 0.7071 - val_recall: 0.7000
# Epoch 46/50
# 347/347 - 1s - 4ms/step - accuracy: 0.7366 - auc: 0.8112 - loss: 0.5302 - precision: 0.7403 - recall: 0.7289 - val_accuracy: 0.7069 - val_auc: 0.7787 - val_loss: 0.5689 - val_precision: 0.7053 - val_recall: 0.7109
# Epoch 47/50
# 347/347 - 1s - 4ms/step - accuracy: 0.7368 - auc: 0.8112 - loss: 0.5304 - precision: 0.7393 - recall: 0.7315 - val_accuracy: 0.7048 - val_auc: 0.7791 - val_loss: 0.5664 - val_precision: 0.7093 - val_recall: 0.6941
# Epoch 48/50
# 347/347 - 1s - 4ms/step - accuracy: 0.7367 - auc: 0.8130 - loss: 0.5278 - precision: 0.7399 - recall: 0.7302 - val_accuracy: 0.7065 - val_auc: 0.7775 - val_loss: 0.5695 - val_precision: 0.7005 - val_recall: 0.7214
# Epoch 49/50
# 347/347 - 1s - 4ms/step - accuracy: 0.7373 - auc: 0.8144 - loss: 0.5262 - precision: 0.7385 - recall: 0.7348 - val_accuracy: 0.7067 - val_auc: 0.7760 - val_loss: 0.5716 - val_precision: 0.7046 - val_recall: 0.7118
# Epoch 50/50
# 347/347 - 1s - 4ms/step - accuracy: 0.7389 - auc: 0.8144 - loss: 0.5260 - precision: 0.7416 - recall: 0.7332 - val_accuracy: 0.7042 - val_auc: 0.7775 - val_loss: 0.5771 - val_precision: 0.7117 - val_recall: 0.6865

# %%
input_shape = X_train.shape[1:]  # alternativo

inputs = tf.keras.Input(shape=input_shape)
x = layers.Masking(mask_value=0.0)(inputs)
x = layers.Bidirectional(layers.LSTM(64, return_sequences=True))(x)
x = layers.GlobalAveragePooling1D()(x)
x = layers.Dropout(0.2)(x)
x = layers.Dense(32, activation='relu')(x)
outputs = layers.Dense(1, activation='sigmoid')(x)

model_lstm = tf.keras.Model(inputs, outputs)
model_lstm.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=[
        tf.keras.metrics.BinaryAccuracy(name='accuracy'),
        tf.keras.metrics.AUC(name='auc'),
        tf.keras.metrics.Recall(name='recall'),
        tf.keras.metrics.Precision(name='precision')
    ]
)

# Opcional: sample_weight por quantidade de janelas válidas
sample_weights = mask_train.sum(axis=1) / mask_train.shape[1]

# Treinamento
model_lstm.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=50,
    batch_size=64,
    sample_weight=sample_weights,
    verbose=2
)
# Out:
# Epoch 1/50
# 347/347 - 4s - 12ms/step - accuracy: 0.6883 - auc: 0.7519 - loss: 0.4520 - precision: 0.6974 - recall: 0.6651 - val_accuracy: 0.6806 - val_auc: 0.7482 - val_loss: 0.5961 - val_precision: 0.6888 - val_recall: 0.6587
# Epoch 2/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7078 - auc: 0.7700 - loss: 0.4389 - precision: 0.7132 - recall: 0.6952 - val_accuracy: 0.6879 - val_auc: 0.7504 - val_loss: 0.5966 - val_precision: 0.6960 - val_recall: 0.6675
# Epoch 3/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7078 - auc: 0.7720 - loss: 0.4371 - precision: 0.7109 - recall: 0.7004 - val_accuracy: 0.6856 - val_auc: 0.7462 - val_loss: 0.5991 - val_precision: 0.6823 - val_recall: 0.6949
# Epoch 4/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7106 - auc: 0.7757 - loss: 0.4343 - precision: 0.7122 - recall: 0.7068 - val_accuracy: 0.6913 - val_auc: 0.7541 - val_loss: 0.5908 - val_precision: 0.6919 - val_recall: 0.6898
# Epoch 5/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7118 - auc: 0.7774 - loss: 0.4323 - precision: 0.7134 - recall: 0.7079 - val_accuracy: 0.6926 - val_auc: 0.7594 - val_loss: 0.5846 - val_precision: 0.6925 - val_recall: 0.6928
# Epoch 6/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7145 - auc: 0.7805 - loss: 0.4300 - precision: 0.7155 - recall: 0.7121 - val_accuracy: 0.6949 - val_auc: 0.7611 - val_loss: 0.5860 - val_precision: 0.7084 - val_recall: 0.6625
# Epoch 7/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7165 - auc: 0.7827 - loss: 0.4282 - precision: 0.7158 - recall: 0.7182 - val_accuracy: 0.6930 - val_auc: 0.7627 - val_loss: 0.5829 - val_precision: 0.6979 - val_recall: 0.6806
# Epoch 8/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7147 - auc: 0.7847 - loss: 0.4257 - precision: 0.7132 - recall: 0.7183 - val_accuracy: 0.6903 - val_auc: 0.7613 - val_loss: 0.5843 - val_precision: 0.6847 - val_recall: 0.7054
# Epoch 9/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7169 - auc: 0.7858 - loss: 0.4250 - precision: 0.7155 - recall: 0.7201 - val_accuracy: 0.6953 - val_auc: 0.7679 - val_loss: 0.5773 - val_precision: 0.6988 - val_recall: 0.6865
# Epoch 10/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7186 - auc: 0.7860 - loss: 0.4248 - precision: 0.7182 - recall: 0.7196 - val_accuracy: 0.6957 - val_auc: 0.7648 - val_loss: 0.5790 - val_precision: 0.6895 - val_recall: 0.7122
# Epoch 11/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7197 - auc: 0.7889 - loss: 0.4225 - precision: 0.7169 - recall: 0.7262 - val_accuracy: 0.6987 - val_auc: 0.7697 - val_loss: 0.5783 - val_precision: 0.7129 - val_recall: 0.6654
# Epoch 12/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7223 - auc: 0.7901 - loss: 0.4218 - precision: 0.7230 - recall: 0.7207 - val_accuracy: 0.6993 - val_auc: 0.7687 - val_loss: 0.5769 - val_precision: 0.6832 - val_recall: 0.7434
# Epoch 13/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7203 - auc: 0.7911 - loss: 0.4201 - precision: 0.7188 - recall: 0.7237 - val_accuracy: 0.6987 - val_auc: 0.7734 - val_loss: 0.5710 - val_precision: 0.7037 - val_recall: 0.6865
# Epoch 14/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7206 - auc: 0.7916 - loss: 0.4195 - precision: 0.7213 - recall: 0.7190 - val_accuracy: 0.6983 - val_auc: 0.7698 - val_loss: 0.5749 - val_precision: 0.6884 - val_recall: 0.7244
# Epoch 15/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7221 - auc: 0.7927 - loss: 0.4189 - precision: 0.7214 - recall: 0.7237 - val_accuracy: 0.6974 - val_auc: 0.7689 - val_loss: 0.5743 - val_precision: 0.6938 - val_recall: 0.7067
# Epoch 16/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7245 - auc: 0.7949 - loss: 0.4167 - precision: 0.7245 - recall: 0.7245 - val_accuracy: 0.7002 - val_auc: 0.7718 - val_loss: 0.5729 - val_precision: 0.6869 - val_recall: 0.7358
# Epoch 17/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7255 - auc: 0.7963 - loss: 0.4158 - precision: 0.7253 - recall: 0.7259 - val_accuracy: 0.7008 - val_auc: 0.7711 - val_loss: 0.5743 - val_precision: 0.7074 - val_recall: 0.6848
# Epoch 18/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7251 - auc: 0.7958 - loss: 0.4161 - precision: 0.7249 - recall: 0.7255 - val_accuracy: 0.7021 - val_auc: 0.7753 - val_loss: 0.5686 - val_precision: 0.6987 - val_recall: 0.7105
# Epoch 19/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7265 - auc: 0.7971 - loss: 0.4144 - precision: 0.7243 - recall: 0.7313 - val_accuracy: 0.6976 - val_auc: 0.7733 - val_loss: 0.5718 - val_precision: 0.6851 - val_recall: 0.7316
# Epoch 20/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7257 - auc: 0.7977 - loss: 0.4139 - precision: 0.7255 - recall: 0.7262 - val_accuracy: 0.7023 - val_auc: 0.7732 - val_loss: 0.5718 - val_precision: 0.7012 - val_recall: 0.7050
# Epoch 21/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7275 - auc: 0.7984 - loss: 0.4133 - precision: 0.7254 - recall: 0.7323 - val_accuracy: 0.7025 - val_auc: 0.7758 - val_loss: 0.5678 - val_precision: 0.6972 - val_recall: 0.7160
# Epoch 22/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7291 - auc: 0.7995 - loss: 0.4122 - precision: 0.7286 - recall: 0.7302 - val_accuracy: 0.7035 - val_auc: 0.7743 - val_loss: 0.5707 - val_precision: 0.6991 - val_recall: 0.7147
# Epoch 23/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7287 - auc: 0.8017 - loss: 0.4100 - precision: 0.7277 - recall: 0.7310 - val_accuracy: 0.7038 - val_auc: 0.7742 - val_loss: 0.5740 - val_precision: 0.6852 - val_recall: 0.7539
# Epoch 24/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7301 - auc: 0.8013 - loss: 0.4105 - precision: 0.7287 - recall: 0.7332 - val_accuracy: 0.7073 - val_auc: 0.7775 - val_loss: 0.5681 - val_precision: 0.7113 - val_recall: 0.6979
# Epoch 25/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7279 - auc: 0.8015 - loss: 0.4093 - precision: 0.7283 - recall: 0.7271 - val_accuracy: 0.7067 - val_auc: 0.7785 - val_loss: 0.5673 - val_precision: 0.6918 - val_recall: 0.7455
# Epoch 26/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7270 - auc: 0.8028 - loss: 0.4077 - precision: 0.7255 - recall: 0.7303 - val_accuracy: 0.7035 - val_auc: 0.7767 - val_loss: 0.5677 - val_precision: 0.6937 - val_recall: 0.7290
# Epoch 27/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7334 - auc: 0.8043 - loss: 0.4075 - precision: 0.7334 - recall: 0.7335 - val_accuracy: 0.7056 - val_auc: 0.7775 - val_loss: 0.5696 - val_precision: 0.6897 - val_recall: 0.7476
# Epoch 28/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7286 - auc: 0.8049 - loss: 0.4065 - precision: 0.7268 - recall: 0.7324 - val_accuracy: 0.7025 - val_auc: 0.7780 - val_loss: 0.5670 - val_precision: 0.7001 - val_recall: 0.7084
# Epoch 29/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7319 - auc: 0.8058 - loss: 0.4058 - precision: 0.7308 - recall: 0.7342 - val_accuracy: 0.6993 - val_auc: 0.7756 - val_loss: 0.5680 - val_precision: 0.6999 - val_recall: 0.6979
# Epoch 30/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7288 - auc: 0.8062 - loss: 0.4050 - precision: 0.7285 - recall: 0.7296 - val_accuracy: 0.7067 - val_auc: 0.7807 - val_loss: 0.5635 - val_precision: 0.6993 - val_recall: 0.7252
# Epoch 31/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7337 - auc: 0.8070 - loss: 0.4043 - precision: 0.7325 - recall: 0.7362 - val_accuracy: 0.7012 - val_auc: 0.7762 - val_loss: 0.5699 - val_precision: 0.7082 - val_recall: 0.6844
# Epoch 32/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7343 - auc: 0.8083 - loss: 0.4025 - precision: 0.7368 - recall: 0.7289 - val_accuracy: 0.7050 - val_auc: 0.7769 - val_loss: 0.5716 - val_precision: 0.7020 - val_recall: 0.7126
# Epoch 33/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7333 - auc: 0.8087 - loss: 0.4024 - precision: 0.7334 - recall: 0.7330 - val_accuracy: 0.6991 - val_auc: 0.7772 - val_loss: 0.5703 - val_precision: 0.7097 - val_recall: 0.6738
# Epoch 34/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7364 - auc: 0.8099 - loss: 0.4016 - precision: 0.7359 - recall: 0.7377 - val_accuracy: 0.7069 - val_auc: 0.7767 - val_loss: 0.5683 - val_precision: 0.6993 - val_recall: 0.7261
# Epoch 35/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7363 - auc: 0.8117 - loss: 0.3996 - precision: 0.7348 - recall: 0.7395 - val_accuracy: 0.7014 - val_auc: 0.7769 - val_loss: 0.5702 - val_precision: 0.6998 - val_recall: 0.7054
# Epoch 36/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7358 - auc: 0.8119 - loss: 0.3990 - precision: 0.7364 - recall: 0.7348 - val_accuracy: 0.7027 - val_auc: 0.7775 - val_loss: 0.5744 - val_precision: 0.7018 - val_recall: 0.7050
# Epoch 37/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7364 - auc: 0.8122 - loss: 0.3987 - precision: 0.7360 - recall: 0.7374 - val_accuracy: 0.7086 - val_auc: 0.7765 - val_loss: 0.5696 - val_precision: 0.7092 - val_recall: 0.7071
# Epoch 38/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7372 - auc: 0.8127 - loss: 0.3982 - precision: 0.7358 - recall: 0.7403 - val_accuracy: 0.7063 - val_auc: 0.7774 - val_loss: 0.5699 - val_precision: 0.7027 - val_recall: 0.7151
# Epoch 39/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7365 - auc: 0.8135 - loss: 0.3976 - precision: 0.7384 - recall: 0.7326 - val_accuracy: 0.7067 - val_auc: 0.7754 - val_loss: 0.5717 - val_precision: 0.7079 - val_recall: 0.7038
# Epoch 40/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7386 - auc: 0.8151 - loss: 0.3956 - precision: 0.7396 - recall: 0.7366 - val_accuracy: 0.7052 - val_auc: 0.7746 - val_loss: 0.5725 - val_precision: 0.7022 - val_recall: 0.7126
# Epoch 41/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7411 - auc: 0.8161 - loss: 0.3947 - precision: 0.7411 - recall: 0.7411 - val_accuracy: 0.6997 - val_auc: 0.7747 - val_loss: 0.5729 - val_precision: 0.7008 - val_recall: 0.6970
# Epoch 42/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7405 - auc: 0.8175 - loss: 0.3932 - precision: 0.7387 - recall: 0.7444 - val_accuracy: 0.7059 - val_auc: 0.7759 - val_loss: 0.5745 - val_precision: 0.6915 - val_recall: 0.7434
# Epoch 43/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7393 - auc: 0.8187 - loss: 0.3920 - precision: 0.7375 - recall: 0.7431 - val_accuracy: 0.7061 - val_auc: 0.7737 - val_loss: 0.5777 - val_precision: 0.7029 - val_recall: 0.7139
# Epoch 44/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7417 - auc: 0.8197 - loss: 0.3905 - precision: 0.7434 - recall: 0.7381 - val_accuracy: 0.7016 - val_auc: 0.7758 - val_loss: 0.5711 - val_precision: 0.7083 - val_recall: 0.6856
# Epoch 45/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7422 - auc: 0.8195 - loss: 0.3911 - precision: 0.7419 - recall: 0.7427 - val_accuracy: 0.6936 - val_auc: 0.7683 - val_loss: 0.5791 - val_precision: 0.6928 - val_recall: 0.6957
# Epoch 46/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7414 - auc: 0.8210 - loss: 0.3895 - precision: 0.7416 - recall: 0.7411 - val_accuracy: 0.7021 - val_auc: 0.7702 - val_loss: 0.5800 - val_precision: 0.6941 - val_recall: 0.7227
# Epoch 47/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7379 - auc: 0.8189 - loss: 0.3906 - precision: 0.7351 - recall: 0.7438 - val_accuracy: 0.6966 - val_auc: 0.7717 - val_loss: 0.5827 - val_precision: 0.7161 - val_recall: 0.6515
# Epoch 48/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7451 - auc: 0.8230 - loss: 0.3870 - precision: 0.7489 - recall: 0.7373 - val_accuracy: 0.7029 - val_auc: 0.7761 - val_loss: 0.5783 - val_precision: 0.7102 - val_recall: 0.6856
# Epoch 49/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7423 - auc: 0.8225 - loss: 0.3870 - precision: 0.7447 - recall: 0.7375 - val_accuracy: 0.7038 - val_auc: 0.7730 - val_loss: 0.5764 - val_precision: 0.7050 - val_recall: 0.7008
# Epoch 50/50
# 347/347 - 2s - 6ms/step - accuracy: 0.7432 - auc: 0.8231 - loss: 0.3862 - precision: 0.7444 - recall: 0.7408 - val_accuracy: 0.7025 - val_auc: 0.7731 - val_loss: 0.5782 - val_precision: 0.6968 - val_recall: 0.7168

# %% [markdown]
# ### Predição e ajuste de limiar
#
# - **Predição:**
#   O modelo LSTM gera, para cada amostra de teste, uma probabilidade (`y_pred_prob`) de ser positivo (ter sepse). Essas probabilidades são valores contínuos entre 0 e 1.
#
# - **Ajuste de limiar:**
#   Para transformar as probabilidades em classes (0 ou 1), define-se um limiar (threshold), normalmente 0.5.
#   - Se a probabilidade for maior ou igual ao limiar, a previsão é positiva (1).
#   - Se for menor, a previsão é negativa (0).
#
# - **Importância:**
#   O ajuste do limiar pode ser alterado conforme a necessidade do problema, por exemplo, para aumentar o recall ou a precisão, dependendo do objetivo clinico

# %%
# Definir a forma da entrada (janelas, variáveis)
input_shape = X_train.shape[1:]  # (10, 8)

# Construir o modelo aprimorado
inputs = tf.keras.Input(shape=input_shape)

# A camada Masking é ótima para dados faltantes ou preenchidos com zero
x = layers.Masking(mask_value=0.0)(inputs)

# Camada Bidirecional para capturar contexto de ambas as direções
# return_sequences=True é necessário para empilhar com outra camada recorrente
x = layers.Bidirectional(layers.LSTM(64, return_sequences=True))(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.4)(x) # Aumentar um pouco o dropout para um modelo mais complexo

# Segunda camada LSTM para aprender padrões mais profundos
x = layers.Bidirectional(layers.LSTM(32, return_sequences=False))(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.4)(x)

# Camada densa para classificação final
x = layers.Dense(32)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)
x = layers.Dropout(0.5)(x) # Dropout final antes da camada de saída

outputs = layers.Dense(1, activation='sigmoid')(x)

model_lstm = models.Model(inputs, outputs)

# %% [markdown]
# ## Resultados

# %%
# Predição
y_pred_prob = model_lstm.predict(X_test).flatten()

# Ajustar limiar (exemplo: 0.5)
limiar = 0.5
y_pred = (y_pred_prob >= limiar).astype(int)

# Métricas
print(f"Acurácia: {accuracy_score(y_test, y_pred):.4f}")
print(f"AUC: {roc_auc_score(y_test, y_pred_prob):.4f}")
print(f"Precisão: {precision_score(y_test, y_pred):.4f}")
print(f"Revocação: {recall_score(y_test, y_pred):.4f}")
print(f"F1-score: {f1_score(y_test, y_pred):.4f}")

# Matriz de Confusão
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Sem Sepse", "Com Sepse"])
disp.plot(cmap='Blues')
plt.title("Matriz de Confusão - LSTM")
plt.show()
# Out:
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# Acurácia: 0.5706
# AUC: 0.6613
# Precisão: 0.5419
# Revocação: 0.9136
# F1-score: 0.6803

# %%
# Curva ROC
fpr, tpr, _ = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, label=f"ROC (AUC = {roc_auc:.2f})")
plt.plot([0, 1], [0, 1], 'k--', lw=1)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("Taxa de Falsos Positivos (FPR)")
plt.ylabel("Taxa de Verdadeiros Positivos (TPR)")
plt.title("Curva ROC - LSTM")
plt.legend(loc="lower right")
plt.grid(True)
plt.show()

# %%
# Curva Precision-Recall
precision, recall, _ = precision_recall_curve(y_test, y_pred_prob)
ap_score = average_precision_score(y_test, y_pred_prob)

plt.figure()
plt.plot(recall, precision, label=f"AP = {ap_score:.2f}")
plt.xlabel("Recall")
plt.ylabel("Precisão")
plt.title("Curva Precision-Recall - LSTM")
plt.legend(loc="lower left")
plt.grid(True)
plt.show()
